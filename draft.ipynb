# %%
import pandas as pd

import nltk
from nltk.corpus import wordnet
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer

import spacy
from spacy.matcher import Matcher

from thefuzz import fuzz, process

# %% [markdown]
# # Data

# %%
# set pandas to display all rows
pd.set_option('display.max_rows', None)

# %%
# Matched examples
df_matched = pd.read_csv('matched_data.csv')
df_matched
# Out:
#                                              source_1                source_2
# 0                                     Cereals, barley                  barley
# 1                     Other fresh or chilled potatoes                potatoes
# 2                      Fruit, edible; cherries, fresh                cherries
# 3           Bran, sharps and other residues, of maize              maize bran
# 4                                     Cereals, millet                 millets
# 5     Oil seeds; sesamum seeds, whether or not broken             sesame seed
# 6                       Cigarettes containing tobacco              cigarettes
# 7                            Tomato, fresh or chilled                tomatoes
# 8   Pulp, bagasse and other waste of sugar manufac...               beet pulp
# 9   Oil seeds; sunflower seeds, whether or not broken          sunflower seed
# 10                Fruit, edible; figs, fresh or dried                    figs
# 11  Bran, sharps and other residues; of wheat, whe...              wheat bran
# 12               Bananas-of-the-earth, fresh or dried               plantains
# 13                                 Maize (corn) flour               cornflour
# 14  Dairy produce; cheese, processed (not grated o...        processed cheese
# 15                         Fresh or chilled asparagus               asparagus
# 16                               Fresh/dried avocados                avocados
# 17  Pig fat; lard, other than that of heading 0209...                    lard
# 18      Oil seeds; poppy seeds, whether or not broken              poppy seed
# 19                           Grape juice, unfermented             grape juice
# 20                                        Asses, live            equus asinus
# 21  Nuts, edible; chestnuts (castanea spp.), fresh...               chestnuts
# 22                                         Sesame oil              sesame oil
# 23                 Fruit, edible; strawberries, fresh            strawberries
# 24  Vegetables, leguminous; chickpeas (garbanzos),...               chickpeas
# 25                                       Fresh apples             crab apples
# 26                                        Wheat flour             wheat flour
# 27                                  Fresh watermelons             watermelons
# 28  Fruit, edible; sour cherries (Prunus cerasus),...           sour cherries
# 29          Oil seeds; linseed, whether or not broken                 linseed
# 30  Vegetables, leguminous; lentils, shelled, whet...                 lentils
# 31                      Fruit, edible; quinces, fresh                 quinces
# 32   Vegetables, alliaceous; garlic, fresh or chilled                  garlic
# 33            Cocoa (whole or broken), raw or roasted             cocoa beans
# 34  Waxes, other than vegetable, n.e.s. in heading...                 beeswax
# 35                                     Spices, ginger                  ginger
# 36  Vegetable roots and tubers; manioc (cassava), ...                    yuca
# 37                                        Broken rice             broken rice
# 38  Coffee; substitutes containing coffee, in any ...      coffee substitutes
# 39  Vegetables; spinach, New Zealand spinach and o...                 spinach
# 40               Vegetables; olives, fresh or chilled                  olives
# 41                       Other soybeans, even crushed                soybeans
# 42                     Fruit, edible; apricots, fresh                apricots
# 43                                       Cereals, rye                     rye
# 44  Food preparations; of flour, meal, starch, mal...           weaning foods
# 45                            Manioc (cassava) starch                 tapioca
# 46                      Live asses, mules and hinnies                  horses
# 47                             Cereals, grain sorghum                 sorghum
# 48     Oil seeds; cotton seeds, whether or not broken              cottonseed
# 49                                              Copra                   copra
# 50          Fresh/chilled/frozen/dried sweet potatoes           sweetpotatoes
# 51              Fresh/chilled aubergines (egg-plants)               eggplants
# 52  Fruit, edible; bananas, (including plantains),...                 bananas
# 53                                      Cereals, oats                    oats
# 54    Oil seeds; mustard seeds, whether or not broken            mustard seed
# 55                                       Pears, fresh                   pears
# 56  Fres/chil/froz oth.meat/edib.meat offal of rab...             rabbit meat
# 57                                 Cereals, buckwheat               buckwheat
# 58            Meat of goats, fresh, chilled or frozen               goat meat
# 59               Fruit, edible; dates, fresh or dried                   dates
# 60  Nuts, edible; kola nuts (Cola spp.), fresh or ...               kola nuts
# 61                                        Goats, live                   goats
# 62  Dairy produce; buttermilk, curdled milk or cre...              buttermilk
# 63                   Bran and other residues, of rice               rice bran
# 64                             Fresh/dried pineapples              pineapples
# 65  Nuts, edible; pistachios, fresh or dried, whet...              pistachios
# 66                                         Dry grapes                 raisins
# 67                    Butter, fat and oil, from cocoa            cocoa butter
# 68  Nuts, edible; coconuts, fresh or dried, whethe...                coconuts
# 69                                       Sauces, soya                  tamari
# 70                             Fresh papaws (papayas)  pawpaw (carica papaya)
# 71                                        Sheep, live                   sheep
# 72  Fruit, edible; cranberries, bilberries and oth...             cranberries
# 73     Spices; cloves (whole fruit, cloves and stems)                  cloves
# 74                              Fresh/chilled lettuce                cabbages
# 75  Jute and other textile bast fibres; processed ...                    jute
# 76                    Cereals, fonio (Digitaria spp.)       fonio (digitaria)
# 77  Vegetable roots and tubers; taro (Colocasia sp...                    taro
# 78  Fruit, edible; raspberries, blackberries, mulb...             raspberries
# 79  Sugar cane; fit for human consumption, fresh, ...               sugarcane
# 80  Meat and edible meat offal; of camels and othe...          dromedary meat
# 81  Vegetable roots and tubers; yams (Dioscorea sp...                    yams
# 82  Oil seeds; safflower seeds, whether or not broken          safflower seed
# 83  Oleaginous fruits; palm nuts and kernels, whet...            palm kernels
# 84  Molluscs; snails (other than sea snails), live...                  snails
# 85                                            Yoghurt                 yoghurt
# 86               Cereals, quinoa (Chenopodium quinoa)                  quinua
# 87  Vegetable roots and tubers; yautia (Xanthosoma...                  yautia
# 88  locust beans, seaweeds and other algae, sugar ...                  carobs
# 89         Oleaginous fruits, shea nuts (karite nuts)               shea nuts
# 90                                            Ploughs                   plows
# 91  Vegetables, leguminous; pigeon peas (Cajanus c...                     tur
# 92                                               Mate              yerba mate
# 93                                Maize (corn) starch            maize starch
# 94  Fish; smoked (whether or not cooked before or ...             smoked fish
# 95                             Fresh/dried grapefruit             grapefruits
# 96  Dairy produce, butter and other fats and oils ...                  butter
# 97  Oleic acid (industrial monocarboxylic fatty ac...              oleic acid
# 98  Disc harrows, used agricultural, etc.f/soil pr...            disc harrows

# %% [markdown]
# # Fuzzy string matching

# %%
lemmatizer = WordNetLemmatizer()
stemmer = LancasterStemmer()

# %%
def root_words(string):
    wrds = nltk.word_tokenize(string)
    roots = [lemmatizer.lemmatize(word.lower()) for word in wrds]
    #roots = [stemmer.stem(word.lower()) for word in wrds]
    return roots
root_words('computer')
# Out:
# ['computer']

# %%
def get_synonyms(string):
    synonyms = []
    for syn in wordnet.synsets(string):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
    res = []
    for syn in synonyms:
        if '_' in syn:
            res.extend(syn.split('_'))
            #res.append(' '.join(syn.split('_')))
        else:
            res.append(syn)
    return res
get_synonyms('computer')
# Out:
# ['computer',
#  'computing',
#  'machine',
#  'computing',
#  'device',
#  'data',
#  'processor',
#  'electronic',
#  'computer',
#  'information',
#  'processing',
#  'system',
#  'calculator',
#  'reckoner',
#  'figurer',
#  'estimator',
#  'computer']

# %%
def get_match(source_1, source_2):
    def get_ratios(i, j):
        print(f"'{i}' vs '{j}'")

        ratio = fuzz.ratio(i, j)
        print(f"Ratio : {ratio}")

        partial_ratio = fuzz.partial_ratio(root_words(i)[0], j)
        print(f"Partial Ratio : {partial_ratio}")

        token_sort_ratio = fuzz.token_sort_ratio(i, j)
        print(f"Token sort Ratio : {token_sort_ratio}")

        token_set_ratio = fuzz.token_set_ratio(i, j)
        print(f"Token set Ratio : {token_set_ratio}")
        print()

        return partial_ratio, token_set_ratio

    for i in source_2:
        i = i.strip()
        synonyms = get_synonyms(i) if ' ' not in i else None
        all_synonyms = ''
        if synonyms:
            synonym_str = ' '.join(synonyms)
            all_synonyms = i + ' ' + synonym_str

        for j in source_1:
            token_set_ratio = get_ratios(i, j)[1]
            if token_set_ratio == 100:
                break
            if len(all_synonyms) > 0:
                partial_ratio = get_ratios(all_synonyms, j)[0]
                if partial_ratio > 80:
                    break
            else:
                continue

# %%
src_1 = df_matched.source_1
src_2 = df_matched.source_2
get_match(src_1, src_2)
# Out:
# 'barley' vs 'Cereals, barley'
# Ratio : 57
# Partial Ratio : 100
# Token sort Ratio : 60
# Token set Ratio : 100
#
# 'potatoes' vs 'Cereals, barley'
# Ratio : 17
# Partial Ratio : 17
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'potatoes potato white potato Irish potato murphy spud tater potato white potato white potato vine Solanum tuberosum' vs 'Cereals, barley'
# Ratio : 14
# Partial Ratio : 17
# Token sort Ratio : 11
# Token set Ratio : 17
#
# 'potatoes' vs 'Other fresh or chilled potatoes'
# Ratio : 41
# Partial Ratio : 100
# Token sort Ratio : 41
# Token set Ratio : 100
#
# 'cherries' vs 'Cereals, barley'
# Ratio : 35
# Partial Ratio : 33
# Token sort Ratio : 45
# Token set Ratio : 45
#
# 'cherries cherry cherry cherry tree cherry cerise cherry cherry red' vs 'Cereals, barley'
# Ratio : 20
# Partial Ratio : 33
# Token sort Ratio : 20
# Token set Ratio : 36
#
# 'cherries' vs 'Other fresh or chilled potatoes'
# Ratio : 36
# Partial Ratio : 50
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'cherries cherry cherry cherry tree cherry cerise cherry cherry red' vs 'Other fresh or chilled potatoes'
# Ratio : 35
# Partial Ratio : 50
# Token sort Ratio : 35
# Token set Ratio : 45
#
# 'cherries' vs 'Fruit, edible; cherries, fresh'
# Ratio : 42
# Partial Ratio : 83
# Token sort Ratio : 46
# Token set Ratio : 100
#
# 'maize bran' vs 'Cereals, barley'
# Ratio : 32
# Partial Ratio : 40
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'maize bran' vs 'Other fresh or chilled potatoes'
# Ratio : 20
# Partial Ratio : 40
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'maize bran' vs 'Fruit, edible; cherries, fresh'
# Ratio : 20
# Partial Ratio : 40
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'maize bran' vs 'Bran, sharps and other residues, of maize'
# Ratio : 20
# Partial Ratio : 100
# Token sort Ratio : 41
# Token set Ratio : 100
#
# 'millets' vs 'Cereals, barley'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'millets millet Millet Jean Francois Millet millet' vs 'Cereals, barley'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 25
# Token set Ratio : 29
#
# 'millets' vs 'Other fresh or chilled potatoes'
# Ratio : 32
# Partial Ratio : 67
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'millets millet Millet Jean Francois Millet millet' vs 'Other fresh or chilled potatoes'
# Ratio : 32
# Partial Ratio : 67
# Token sort Ratio : 32
# Token set Ratio : 31
#
# 'millets' vs 'Fruit, edible; cherries, fresh'
# Ratio : 22
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'millets millet Millet Jean Francois Millet millet' vs 'Fruit, edible; cherries, fresh'
# Ratio : 35
# Partial Ratio : 50
# Token sort Ratio : 37
# Token set Ratio : 40
#
# 'millets' vs 'Bran, sharps and other residues, of maize'
# Ratio : 12
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'millets millet Millet Jean Francois Millet millet' vs 'Bran, sharps and other residues, of maize'
# Ratio : 31
# Partial Ratio : 50
# Token sort Ratio : 39
# Token set Ratio : 42
#
# 'millets' vs 'Cereals, millet'
# Ratio : 55
# Partial Ratio : 100
# Token sort Ratio : 57
# Token set Ratio : 57
#
# 'millets millet Millet Jean Francois Millet millet' vs 'Cereals, millet'
# Ratio : 34
# Partial Ratio : 100
# Token sort Ratio : 35
# Token set Ratio : 60
#
# 'sesame seed' vs 'Cereals, barley'
# Ratio : 31
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sesame seed' vs 'Other fresh or chilled potatoes'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sesame seed' vs 'Fruit, edible; cherries, fresh'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sesame seed' vs 'Bran, sharps and other residues, of maize'
# Ratio : 31
# Partial Ratio : 33
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'sesame seed' vs 'Cereals, millet'
# Ratio : 31
# Partial Ratio : 33
# Token sort Ratio : 40
# Token set Ratio : 40
#
# 'sesame seed' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 34
# Partial Ratio : 83
# Token sort Ratio : 39
# Token set Ratio : 44
#
# 'sesame seed' vs 'Cigarettes containing tobacco'
# Ratio : 20
# Partial Ratio : 33
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'sesame seed' vs 'Tomato, fresh or chilled'
# Ratio : 29
# Partial Ratio : 33
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sesame seed' vs 'Pulp, bagasse and other waste of sugar manufacture'
# Ratio : 26
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'sesame seed' vs 'Oil seeds; sunflower seeds, whether or not broken'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sesame seed' vs 'Fruit, edible; figs, fresh or dried'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sesame seed' vs 'Bran, sharps and other residues; of wheat, whether or not in the form of pellets, derived from the sifting, milling or other workings thereof'
# Ratio : 13
# Partial Ratio : 33
# Token sort Ratio : 12
# Token set Ratio : 14
#
# 'sesame seed' vs 'Bananas-of-the-earth, fresh or dried'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'sesame seed' vs 'Maize (corn) flour'
# Ratio : 21
# Partial Ratio : 17
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'sesame seed' vs 'Dairy produce; cheese, processed (not grated or powdered)'
# Ratio : 26
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'sesame seed' vs 'Fresh or chilled asparagus'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sesame seed' vs 'Fresh/dried avocados'
# Ratio : 32
# Partial Ratio : 33
# Token sort Ratio : 39
# Token set Ratio : 39
#
# 'sesame seed' vs 'Pig fat; lard, other than that of heading 0209 and 1503'
# Ratio : 15
# Partial Ratio : 17
# Token sort Ratio : 16
# Token set Ratio : 16
#
# 'sesame seed' vs 'Oil seeds; poppy seeds, whether or not broken'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 33
# Token set Ratio : 29
#
# 'sesame seed' vs 'Grape juice, unfermented'
# Ratio : 34
# Partial Ratio : 50
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sesame seed' vs 'Asses, live'
# Ratio : 45
# Partial Ratio : 50
# Token sort Ratio : 48
# Token set Ratio : 48
#
# 'sesame seed' vs 'Nuts, edible; chestnuts (castanea spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 20
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'sesame seed' vs 'Sesame oil'
# Ratio : 57
# Partial Ratio : 83
# Token sort Ratio : 67
# Token set Ratio : 75
#
# 'sesame seed' vs 'Fruit, edible; strawberries, fresh'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sesame seed' vs 'Vegetables, leguminous; chickpeas (garbanzos), shelled, whether or not skinned or split, dried'
# Ratio : 19
# Partial Ratio : 33
# Token sort Ratio : 20
# Token set Ratio : 21
#
# 'sesame seed' vs 'Fresh apples'
# Ratio : 43
# Partial Ratio : 50
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sesame seed' vs 'Wheat flour'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'sesame seed' vs 'Fresh watermelons'
# Ratio : 43
# Partial Ratio : 50
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sesame seed' vs 'Fruit, edible; sour cherries (Prunus cerasus), fresh'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'sesame seed' vs 'Oil seeds; linseed, whether or not broken'
# Ratio : 31
# Partial Ratio : 50
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sesame seed' vs 'Vegetables, leguminous; lentils, shelled, whether or not skinned or split, dried'
# Ratio : 20
# Partial Ratio : 33
# Token sort Ratio : 23
# Token set Ratio : 24
#
# 'sesame seed' vs 'Fruit, edible; quinces, fresh'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sesame seed' vs 'Vegetables, alliaceous; garlic, fresh or chilled'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sesame seed' vs 'Cocoa (whole or broken), raw or roasted'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 21
# Token set Ratio : 23
#
# 'sesame seed' vs 'Waxes, other than vegetable, n.e.s. in heading no. 1521; whether or not refined or coloured'
# Ratio : 18
# Partial Ratio : 33
# Token sort Ratio : 16
# Token set Ratio : 17
#
# 'sesame seed' vs 'Spices, ginger'
# Ratio : 32
# Partial Ratio : 33
# Token sort Ratio : 42
# Token set Ratio : 42
#
# 'sesame seed' vs 'Vegetable roots and tubers; manioc (cassava), with high starch or inulin content, whether or not sliced or in the form of pellets, fresh or dried'
# Ratio : 13
# Partial Ratio : 50
# Token sort Ratio : 13
# Token set Ratio : 14
#
# 'sesame seed' vs 'Broken rice'
# Ratio : 27
# Partial Ratio : 17
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'sesame seed' vs 'Coffee; substitutes containing coffee, in any proportion'
# Ratio : 21
# Partial Ratio : 33
# Token sort Ratio : 18
# Token set Ratio : 21
#
# 'sesame seed' vs 'Vegetables; spinach, New Zealand spinach and orache spinach (garden spinach), fresh or chilled'
# Ratio : 19
# Partial Ratio : 33
# Token sort Ratio : 16
# Token set Ratio : 21
#
# 'sesame seed' vs 'Vegetables; olives, fresh or chilled'
# Ratio : 34
# Partial Ratio : 33
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sesame seed' vs 'Other soybeans, even crushed'
# Ratio : 41
# Partial Ratio : 50
# Token sort Ratio : 37
# Token set Ratio : 37
#
# 'sesame seed' vs 'Fruit, edible; apricots, fresh'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sesame seed' vs 'Cereals, rye'
# Ratio : 35
# Partial Ratio : 33
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sesame seed' vs 'Food preparations; of flour, meal, starch, malt extract or milk products, for infant use, put up for retail sale'
# Ratio : 16
# Partial Ratio : 50
# Token sort Ratio : 15
# Token set Ratio : 16
#
# 'sesame seed' vs 'Manioc (cassava) starch'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'sesame seed' vs 'Live asses, mules and hinnies'
# Ratio : 35
# Partial Ratio : 67
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sesame seed' vs 'Cereals, grain sorghum'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sesame seed' vs 'Oil seeds; cotton seeds, whether or not broken'
# Ratio : 28
# Partial Ratio : 50
# Token sort Ratio : 33
# Token set Ratio : 29
#
# 'sesame seed' vs 'Copra'
# Ratio : 12
# Partial Ratio : 20
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'sesame seed' vs 'Fresh/chilled/frozen/dried sweet potatoes'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sesame seed' vs 'Fresh/chilled aubergines (egg-plants)'
# Ratio : 25
# Partial Ratio : 50
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'sesame seed' vs 'Fruit, edible; bananas, (including plantains), fresh or dried'
# Ratio : 19
# Partial Ratio : 17
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'sesame seed' vs 'Cereals, oats'
# Ratio : 33
# Partial Ratio : 33
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sesame seed' vs 'Oil seeds; mustard seeds, whether or not broken'
# Ratio : 31
# Partial Ratio : 50
# Token sort Ratio : 32
# Token set Ratio : 28
#
# 'sesame seed' vs 'Pears, fresh'
# Ratio : 35
# Partial Ratio : 33
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sesame seed' vs 'Fres/chil/froz oth.meat/edib.meat offal of rabib./hares'
# Ratio : 21
# Partial Ratio : 33
# Token sort Ratio : 28
# Token set Ratio : 27
#
# 'sesame seed' vs 'Cereals, buckwheat'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sesame seed' vs 'Meat of goats, fresh, chilled or frozen'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sesame seed' vs 'Fruit, edible; dates, fresh or dried'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sesame seed' vs 'Nuts, edible; kola nuts (Cola spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 21
# Partial Ratio : 33
# Token sort Ratio : 20
# Token set Ratio : 23
#
# 'sesame seed' vs 'Goats, live'
# Ratio : 27
# Partial Ratio : 17
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sesame seed' vs 'Dairy produce; buttermilk, curdled milk or cream, kephir, fermented or acidified milk or cream, whether or not concentrated or containing added sweetening, flavouring, fruit or cocoa (excluding yoghurt)'
# Ratio : 8
# Partial Ratio : 50
# Token sort Ratio : 8
# Token set Ratio : 9
#
# 'sesame seed' vs 'Bran and other residues, of rice'
# Ratio : 28
# Partial Ratio : 50
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sesame seed' vs 'Fresh/dried pineapples'
# Ratio : 36
# Partial Ratio : 50
# Token sort Ratio : 42
# Token set Ratio : 42
#
# 'sesame seed' vs 'Nuts, edible; pistachios, fresh or dried, whether or not shelled or peeled'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 22
# Token set Ratio : 24
#
# 'sesame seed' vs 'Dry grapes'
# Ratio : 29
# Partial Ratio : 33
# Token sort Ratio : 38
# Token set Ratio : 38
#
# 'sesame seed' vs 'Butter, fat and oil, from cocoa'
# Ratio : 19
# Partial Ratio : 17
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'sesame seed' vs 'Nuts, edible; coconuts, fresh or dried, whether or not shelled or peeled'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 23
# Token set Ratio : 25
#
# 'sesame seed' vs 'Sauces, soya'
# Ratio : 35
# Partial Ratio : 33
# Token sort Ratio : 45
# Token set Ratio : 45
#
# 'sesame seed' vs 'Fresh papaws (papayas)'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'sesame seed' vs 'Sheep, live'
# Ratio : 36
# Partial Ratio : 33
# Token sort Ratio : 48
# Token set Ratio : 48
#
# 'sesame seed' vs 'Fruit, edible; cranberries, bilberries and other fruits of the genus vaccinium, fresh'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'sesame seed' vs 'Spices; cloves (whole fruit, cloves and stems)'
# Ratio : 25
# Partial Ratio : 50
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'sesame seed' vs 'Fresh/chilled lettuce'
# Ratio : 38
# Partial Ratio : 33
# Token sort Ratio : 38
# Token set Ratio : 38
#
# 'sesame seed' vs 'Jute and other textile bast fibres; processed but not spun, tow and waste of these fibres, including yarn waste and garnetted stock (excluding flax, hemp (cannabis sativa L.), and ramie)'
# Ratio : 10
# Partial Ratio : 50
# Token sort Ratio : 11
# Token set Ratio : 12
#
# 'sesame seed' vs 'Cereals, fonio (Digitaria spp.)'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'sesame seed' vs 'Vegetable roots and tubers; taro (Colocasia spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 11
# Partial Ratio : 33
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'sesame seed' vs 'Fruit, edible; raspberries, blackberries, mulberries and loganberries, fresh'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'sesame seed' vs 'Sugar cane; fit for human consumption, fresh, chilled, frozen or dried, whether or not ground'
# Ratio : 15
# Partial Ratio : 33
# Token sort Ratio : 18
# Token set Ratio : 19
#
# 'sesame seed' vs 'Meat and edible meat offal; of camels and other camelids (Camelidae), fresh, chilled or frozen'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'sesame seed' vs 'Vegetable roots and tubers; yams (Dioscorea spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 12
# Partial Ratio : 33
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'sesame seed' vs 'Oil seeds; safflower seeds, whether or not broken'
# Ratio : 33
# Partial Ratio : 50
# Token sort Ratio : 31
# Token set Ratio : 27
#
# 'sesame seed' vs 'Oleaginous fruits; palm nuts and kernels, whether or not broken'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'sesame seed' vs 'Molluscs; snails (other than sea snails), live, fresh, chilled, frozen, dried, salted or in brine (whether in shell or not)'
# Ratio : 15
# Partial Ratio : 50
# Token sort Ratio : 16
# Token set Ratio : 18
#
# 'sesame seed' vs 'Yoghurt'
# Ratio : 0
# Partial Ratio : 0
# Token sort Ratio : 0
# Token set Ratio : 0
#
# 'sesame seed' vs 'Cereals, quinoa (Chenopodium quinoa)'
# Ratio : 26
# Partial Ratio : 33
# Token sort Ratio : 23
# Token set Ratio : 27
#
# 'sesame seed' vs 'Vegetable roots and tubers; yautia (Xanthosoma spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 12
# Partial Ratio : 33
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'sesame seed' vs 'locust beans, seaweeds and other algae, sugar beet and sugar cane, fresh, chilled, frozen or dried, whether or not ground; fruit stones and kernels and other vegetable products (including unroasted chicory roots of the variety cichorium intybus sativum) of a kind used primarily for human consumption, not elsewhere specified or included; seaweeds and other algae other than fit for human consumption'
# Ratio : 5
# Partial Ratio : 67
# Token sort Ratio : 6
# Token set Ratio : 7
#
# 'sesame seed' vs 'Oleaginous fruits, shea nuts (karite nuts)'
# Ratio : 26
# Partial Ratio : 33
# Token sort Ratio : 28
# Token set Ratio : 31
#
# 'sesame seed' vs 'Ploughs'
# Ratio : 11
# Partial Ratio : 17
# Token sort Ratio : 11
# Token set Ratio : 11
#
# 'sesame seed' vs 'Vegetables, leguminous; pigeon peas (Cajanus cajan), shelled, whether or not skinned or split, dried'
# Ratio : 18
# Partial Ratio : 33
# Token sort Ratio : 19
# Token set Ratio : 20
#
# 'sesame seed' vs 'Mate'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'sesame seed' vs 'Maize (corn) starch'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sesame seed' vs 'Fish; smoked (whether or not cooked before or during the smoking process), n.e.s. in item no. 0305.4 (including fillets)'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 15
# Token set Ratio : 15
#
# 'sesame seed' vs 'Fresh/dried grapefruit'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 42
# Token set Ratio : 42
#
# 'sesame seed' vs 'Dairy produce, butter and other fats and oils derived from milk'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 19
# Token set Ratio : 20
#
# 'sesame seed' vs 'Oleic acid (industrial monocarboxylic fatty acids)'
# Ratio : 20
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'sesame seed' vs 'Disc harrows, used agricultural, etc.f/soil preparation'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'cigarettes' vs 'Cereals, barley'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 42
# Token set Ratio : 42
#
# 'cigarettes cigarette cigaret coffin nail butt fag' vs 'Cereals, barley'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'cigarettes' vs 'Other fresh or chilled potatoes'
# Ratio : 34
# Partial Ratio : 33
# Token sort Ratio : 39
# Token set Ratio : 39
#
# 'cigarettes cigarette cigaret coffin nail butt fag' vs 'Other fresh or chilled potatoes'
# Ratio : 35
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'cigarettes' vs 'Fruit, edible; cherries, fresh'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'cigarettes cigarette cigaret coffin nail butt fag' vs 'Fruit, edible; cherries, fresh'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'cigarettes' vs 'Bran, sharps and other residues, of maize'
# Ratio : 20
# Partial Ratio : 22
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'cigarettes cigarette cigaret coffin nail butt fag' vs 'Bran, sharps and other residues, of maize'
# Ratio : 36
# Partial Ratio : 22
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'cigarettes' vs 'Cereals, millet'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'cigarettes cigarette cigaret coffin nail butt fag' vs 'Cereals, millet'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'cigarettes' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 21
# Partial Ratio : 33
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'cigarettes cigarette cigaret coffin nail butt fag' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 35
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 32
#
# 'cigarettes' vs 'Cigarettes containing tobacco'
# Ratio : 46
# Partial Ratio : 89
# Token sort Ratio : 51
# Token set Ratio : 100
#
# 'tomatoes' vs 'Cereals, barley'
# Ratio : 17
# Partial Ratio : 17
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Cereals, barley'
# Ratio : 21
# Partial Ratio : 17
# Token sort Ratio : 21
# Token set Ratio : 26
#
# 'tomatoes' vs 'Other fresh or chilled potatoes'
# Ratio : 36
# Partial Ratio : 67
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Other fresh or chilled potatoes'
# Ratio : 34
# Partial Ratio : 67
# Token sort Ratio : 40
# Token set Ratio : 46
#
# 'tomatoes' vs 'Fruit, edible; cherries, fresh'
# Ratio : 16
# Partial Ratio : 17
# Token sort Ratio : 11
# Token set Ratio : 11
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Fruit, edible; cherries, fresh'
# Ratio : 26
# Partial Ratio : 17
# Token sort Ratio : 23
# Token set Ratio : 27
#
# 'tomatoes' vs 'Bran, sharps and other residues, of maize'
# Ratio : 20
# Partial Ratio : 50
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Bran, sharps and other residues, of maize'
# Ratio : 31
# Partial Ratio : 50
# Token sort Ratio : 31
# Token set Ratio : 32
#
# 'tomatoes' vs 'Cereals, millet'
# Ratio : 17
# Partial Ratio : 33
# Token sort Ratio : 18
# Token set Ratio : 18
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Cereals, millet'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 19
# Token set Ratio : 23
#
# 'tomatoes' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 32
# Partial Ratio : 50
# Token sort Ratio : 31
# Token set Ratio : 34
#
# 'tomatoes' vs 'Cigarettes containing tobacco'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Cigarettes containing tobacco'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 30
# Token set Ratio : 35
#
# 'tomatoes' vs 'Tomato, fresh or chilled'
# Ratio : 44
# Partial Ratio : 83
# Token sort Ratio : 39
# Token set Ratio : 39
#
# 'tomatoes tomato tomato love apple tomato plant Lycopersicon esculentum' vs 'Tomato, fresh or chilled'
# Ratio : 30
# Partial Ratio : 83
# Token sort Ratio : 34
# Token set Ratio : 41
#
# 'beet pulp' vs 'Cereals, barley'
# Ratio : 33
# Partial Ratio : 25
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'beet pulp' vs 'Other fresh or chilled potatoes'
# Ratio : 25
# Partial Ratio : 25
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Fruit, edible; cherries, fresh'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'beet pulp' vs 'Bran, sharps and other residues, of maize'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Cereals, millet'
# Ratio : 33
# Partial Ratio : 50
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'beet pulp' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'beet pulp' vs 'Cigarettes containing tobacco'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'beet pulp' vs 'Tomato, fresh or chilled'
# Ratio : 18
# Partial Ratio : 25
# Token sort Ratio : 19
# Token set Ratio : 19
#
# 'beet pulp' vs 'Pulp, bagasse and other waste of sugar manufacture'
# Ratio : 20
# Partial Ratio : 25
# Token sort Ratio : 31
# Token set Ratio : 62
#
# 'beet pulp' vs 'Oil seeds; sunflower seeds, whether or not broken'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 21
# Token set Ratio : 24
#
# 'beet pulp' vs 'Fruit, edible; figs, fresh or dried'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'beet pulp' vs 'Bran, sharps and other residues; of wheat, whether or not in the form of pellets, derived from the sifting, milling or other workings thereof'
# Ratio : 8
# Partial Ratio : 50
# Token sort Ratio : 11
# Token set Ratio : 12
#
# 'beet pulp' vs 'Bananas-of-the-earth, fresh or dried'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'beet pulp' vs 'Maize (corn) flour'
# Ratio : 22
# Partial Ratio : 25
# Token sort Ratio : 16
# Token set Ratio : 16
#
# 'beet pulp' vs 'Dairy produce; cheese, processed (not grated or powdered)'
# Ratio : 15
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 19
#
# 'beet pulp' vs 'Fresh or chilled asparagus'
# Ratio : 29
# Partial Ratio : 25
# Token sort Ratio : 17
# Token set Ratio : 17
#
# 'beet pulp' vs 'Fresh/dried avocados'
# Ratio : 21
# Partial Ratio : 25
# Token sort Ratio : 14
# Token set Ratio : 14
#
# 'beet pulp' vs 'Pig fat; lard, other than that of heading 0209 and 1503'
# Ratio : 9
# Partial Ratio : 25
# Token sort Ratio : 13
# Token set Ratio : 13
#
# 'beet pulp' vs 'Oil seeds; poppy seeds, whether or not broken'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 23
# Token set Ratio : 26
#
# 'beet pulp' vs 'Grape juice, unfermented'
# Ratio : 24
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Asses, live'
# Ratio : 30
# Partial Ratio : 25
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'beet pulp' vs 'Nuts, edible; chestnuts (castanea spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 16
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 19
#
# 'beet pulp' vs 'Sesame oil'
# Ratio : 42
# Partial Ratio : 25
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'beet pulp' vs 'Fruit, edible; strawberries, fresh'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Vegetables, leguminous; chickpeas (garbanzos), shelled, whether or not skinned or split, dried'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 12
# Token set Ratio : 13
#
# 'beet pulp' vs 'Fresh apples'
# Ratio : 38
# Partial Ratio : 25
# Token sort Ratio : 19
# Token set Ratio : 19
#
# 'beet pulp' vs 'Wheat flour'
# Ratio : 40
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'beet pulp' vs 'Fresh watermelons'
# Ratio : 23
# Partial Ratio : 25
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'beet pulp' vs 'Fruit, edible; sour cherries (Prunus cerasus), fresh'
# Ratio : 16
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Oil seeds; linseed, whether or not broken'
# Ratio : 16
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Vegetables, leguminous; lentils, shelled, whether or not skinned or split, dried'
# Ratio : 16
# Partial Ratio : 50
# Token sort Ratio : 14
# Token set Ratio : 15
#
# 'beet pulp' vs 'Fruit, edible; quinces, fresh'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'beet pulp' vs 'Vegetables, alliaceous; garlic, fresh or chilled'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 15
# Token set Ratio : 15
#
# 'beet pulp' vs 'Cocoa (whole or broken), raw or roasted'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 22
# Token set Ratio : 24
#
# 'beet pulp' vs 'Waxes, other than vegetable, n.e.s. in heading no. 1521; whether or not refined or coloured'
# Ratio : 12
# Partial Ratio : 50
# Token sort Ratio : 11
# Token set Ratio : 11
#
# 'beet pulp' vs 'Spices, ginger'
# Ratio : 17
# Partial Ratio : 25
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'beet pulp' vs 'Vegetable roots and tubers; manioc (cassava), with high starch or inulin content, whether or not sliced or in the form of pellets, fresh or dried'
# Ratio : 10
# Partial Ratio : 50
# Token sort Ratio : 9
# Token set Ratio : 10
#
# 'beet pulp' vs 'Broken rice'
# Ratio : 20
# Partial Ratio : 25
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'beet pulp' vs 'Coffee; substitutes containing coffee, in any proportion'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'beet pulp' vs 'Vegetables; spinach, New Zealand spinach and orache spinach (garden spinach), fresh or chilled'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 10
# Token set Ratio : 14
#
# 'beet pulp' vs 'Vegetables; olives, fresh or chilled'
# Ratio : 22
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 19
#
# 'beet pulp' vs 'Other soybeans, even crushed'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'beet pulp' vs 'Fruit, edible; apricots, fresh'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'beet pulp' vs 'Cereals, rye'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'beet pulp' vs 'Food preparations; of flour, meal, starch, malt extract or milk products, for infant use, put up for retail sale'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 14
# Token set Ratio : 14
#
# 'beet pulp' vs 'Manioc (cassava) starch'
# Ratio : 6
# Partial Ratio : 25
# Token sort Ratio : 7
# Token set Ratio : 7
#
# 'beet pulp' vs 'Live asses, mules and hinnies'
# Ratio : 26
# Partial Ratio : 25
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'beet pulp' vs 'Cereals, grain sorghum'
# Ratio : 26
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'beet pulp' vs 'Oil seeds; cotton seeds, whether or not broken'
# Ratio : 15
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'beet pulp' vs 'Copra'
# Ratio : 14
# Partial Ratio : 0
# Token sort Ratio : 14
# Token set Ratio : 14
#
# 'beet pulp' vs 'Fresh/chilled/frozen/dried sweet potatoes'
# Ratio : 20
# Partial Ratio : 75
# Token sort Ratio : 16
# Token set Ratio : 16
#
# 'beet pulp' vs 'Fresh/chilled aubergines (egg-plants)'
# Ratio : 26
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'beet pulp' vs 'Fruit, edible; bananas, (including plantains), fresh or dried'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'beet pulp' vs 'Cereals, oats'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'beet pulp' vs 'Oil seeds; mustard seeds, whether or not broken'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'beet pulp' vs 'Pears, fresh'
# Ratio : 19
# Partial Ratio : 25
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'beet pulp' vs 'Fres/chil/froz oth.meat/edib.meat offal of rabib./hares'
# Ratio : 16
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 21
#
# 'beet pulp' vs 'Cereals, buckwheat'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 38
# Token set Ratio : 38
#
# 'beet pulp' vs 'Meat of goats, fresh, chilled or frozen'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 17
# Token set Ratio : 17
#
# 'beet pulp' vs 'Fruit, edible; dates, fresh or dried'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'beet pulp' vs 'Nuts, edible; kola nuts (Cola spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 15
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 21
#
# 'beet pulp' vs 'Goats, live'
# Ratio : 30
# Partial Ratio : 25
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'beet pulp' vs 'Dairy produce; buttermilk, curdled milk or cream, kephir, fermented or acidified milk or cream, whether or not concentrated or containing added sweetening, flavouring, fruit or cocoa (excluding yoghurt)'
# Ratio : 7
# Partial Ratio : 50
# Token sort Ratio : 8
# Token set Ratio : 9
#
# 'beet pulp' vs 'Bran and other residues, of rice'
# Ratio : 15
# Partial Ratio : 25
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'beet pulp' vs 'Fresh/dried pineapples'
# Ratio : 32
# Partial Ratio : 25
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'beet pulp' vs 'Nuts, edible; pistachios, fresh or dried, whether or not shelled or peeled'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 22
#
# 'beet pulp' vs 'Dry grapes'
# Ratio : 21
# Partial Ratio : 25
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'beet pulp' vs 'Butter, fat and oil, from cocoa'
# Ratio : 20
# Partial Ratio : 25
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'beet pulp' vs 'Nuts, edible; coconuts, fresh or dried, whether or not shelled or peeled'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'beet pulp' vs 'Sauces, soya'
# Ratio : 19
# Partial Ratio : 25
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'beet pulp' vs 'Fresh papaws (papayas)'
# Ratio : 26
# Partial Ratio : 25
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'beet pulp' vs 'Sheep, live'
# Ratio : 40
# Partial Ratio : 50
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'beet pulp' vs 'Fruit, edible; cranberries, bilberries and other fruits of the genus vaccinium, fresh'
# Ratio : 13
# Partial Ratio : 50
# Token sort Ratio : 13
# Token set Ratio : 13
#
# 'beet pulp' vs 'Spices; cloves (whole fruit, cloves and stems)'
# Ratio : 18
# Partial Ratio : 25
# Token sort Ratio : 24
# Token set Ratio : 23
#
# 'beet pulp' vs 'Fresh/chilled lettuce'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'beet pulp' vs 'Jute and other textile bast fibres; processed but not spun, tow and waste of these fibres, including yarn waste and garnetted stock (excluding flax, hemp (cannabis sativa L.), and ramie)'
# Ratio : 9
# Partial Ratio : 50
# Token sort Ratio : 10
# Token set Ratio : 11
#
# 'beet pulp' vs 'Cereals, fonio (Digitaria spp.)'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'beet pulp' vs 'Vegetable roots and tubers; taro (Colocasia spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 10
# Partial Ratio : 50
# Token sort Ratio : 8
# Token set Ratio : 9
#
# 'beet pulp' vs 'Fruit, edible; raspberries, blackberries, mulberries and loganberries, fresh'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 20
#
# 'beet pulp' vs 'Sugar cane; fit for human consumption, fresh, chilled, frozen or dried, whether or not ground'
# Ratio : 10
# Partial Ratio : 50
# Token sort Ratio : 10
# Token set Ratio : 11
#
# 'beet pulp' vs 'Meat and edible meat offal; of camels and other camelids (Camelidae), fresh, chilled or frozen'
# Ratio : 12
# Partial Ratio : 50
# Token sort Ratio : 12
# Token set Ratio : 13
#
# 'beet pulp' vs 'Vegetable roots and tubers; yams (Dioscorea spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 9
# Partial Ratio : 50
# Token sort Ratio : 8
# Token set Ratio : 9
#
# 'beet pulp' vs 'Oil seeds; safflower seeds, whether or not broken'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'beet pulp' vs 'Oleaginous fruits; palm nuts and kernels, whether or not broken'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'beet pulp' vs 'Molluscs; snails (other than sea snails), live, fresh, chilled, frozen, dried, salted or in brine (whether in shell or not)'
# Ratio : 9
# Partial Ratio : 50
# Token sort Ratio : 10
# Token set Ratio : 11
#
# 'beet pulp' vs 'Yoghurt'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'beet pulp' vs 'Cereals, quinoa (Chenopodium quinoa)'
# Ratio : 22
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 29
#
# 'beet pulp' vs 'Vegetable roots and tubers; yautia (Xanthosoma spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 10
# Partial Ratio : 50
# Token sort Ratio : 8
# Token set Ratio : 9
#
# 'beet pulp' vs 'locust beans, seaweeds and other algae, sugar beet and sugar cane, fresh, chilled, frozen or dried, whether or not ground; fruit stones and kernels and other vegetable products (including unroasted chicory roots of the variety cichorium intybus sativum) of a kind used primarily for human consumption, not elsewhere specified or included; seaweeds and other algae other than fit for human consumption'
# Ratio : 4
# Partial Ratio : 50
# Token sort Ratio : 5
# Token set Ratio : 62
#
# 'beet pulp' vs 'Oleaginous fruits, shea nuts (karite nuts)'
# Ratio : 20
# Partial Ratio : 25
# Token sort Ratio : 21
# Token set Ratio : 19
#
# 'beet pulp' vs 'Ploughs'
# Ratio : 12
# Partial Ratio : 0
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'beet pulp' vs 'Vegetables, leguminous; pigeon peas (Cajanus cajan), shelled, whether or not skinned or split, dried'
# Ratio : 15
# Partial Ratio : 50
# Token sort Ratio : 14
# Token set Ratio : 14
#
# 'beet pulp' vs 'Mate'
# Ratio : 15
# Partial Ratio : 25
# Token sort Ratio : 15
# Token set Ratio : 15
#
# 'beet pulp' vs 'Maize (corn) starch'
# Ratio : 14
# Partial Ratio : 25
# Token sort Ratio : 15
# Token set Ratio : 15
#
# 'beet pulp' vs 'Fish; smoked (whether or not cooked before or during the smoking process), n.e.s. in item no. 0305.4 (including fillets)'
# Ratio : 12
# Partial Ratio : 50
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'beet pulp' vs 'Fresh/dried grapefruit'
# Ratio : 32
# Partial Ratio : 25
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'beet pulp' vs 'Dairy produce, butter and other fats and oils derived from milk'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 21
#
# 'beet pulp' vs 'Oleic acid (industrial monocarboxylic fatty acids)'
# Ratio : 14
# Partial Ratio : 25
# Token sort Ratio : 14
# Token set Ratio : 14
#
# 'beet pulp' vs 'Disc harrows, used agricultural, etc.f/soil preparation'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 16
# Token set Ratio : 16
#
# 'sunflower seed' vs 'Cereals, barley'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sunflower seed' vs 'Other fresh or chilled potatoes'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Fruit, edible; cherries, fresh'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'sunflower seed' vs 'Bran, sharps and other residues, of maize'
# Ratio : 33
# Partial Ratio : 44
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'sunflower seed' vs 'Cereals, millet'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sunflower seed' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 23
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 38
#
# 'sunflower seed' vs 'Cigarettes containing tobacco'
# Ratio : 14
# Partial Ratio : 22
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'sunflower seed' vs 'Tomato, fresh or chilled'
# Ratio : 32
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sunflower seed' vs 'Pulp, bagasse and other waste of sugar manufacture'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'sunflower seed' vs 'Oil seeds; sunflower seeds, whether or not broken'
# Ratio : 44
# Partial Ratio : 100
# Token sort Ratio : 46
# Token set Ratio : 78
#
# 'sunflower seed' vs 'Fruit, edible; figs, fresh or dried'
# Ratio : 33
# Partial Ratio : 33
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sunflower seed' vs 'Bran, sharps and other residues; of wheat, whether or not in the form of pellets, derived from the sifting, milling or other workings thereof'
# Ratio : 15
# Partial Ratio : 33
# Token sort Ratio : 15
# Token set Ratio : 16
#
# 'sunflower seed' vs 'Bananas-of-the-earth, fresh or dried'
# Ratio : 32
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Maize (corn) flour'
# Ratio : 31
# Partial Ratio : 59
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Dairy produce; cheese, processed (not grated or powdered)'
# Ratio : 25
# Partial Ratio : 44
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'sunflower seed' vs 'Fresh or chilled asparagus'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sunflower seed' vs 'Fresh/dried avocados'
# Ratio : 24
# Partial Ratio : 22
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sunflower seed' vs 'Pig fat; lard, other than that of heading 0209 and 1503'
# Ratio : 23
# Partial Ratio : 33
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'sunflower seed' vs 'Oil seeds; poppy seeds, whether or not broken'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Grape juice, unfermented'
# Ratio : 42
# Partial Ratio : 56
# Token sort Ratio : 43
# Token set Ratio : 43
#
# 'sunflower seed' vs 'Asses, live'
# Ratio : 32
# Partial Ratio : 35
# Token sort Ratio : 42
# Token set Ratio : 42
#
# 'sunflower seed' vs 'Nuts, edible; chestnuts (castanea spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 23
# Token set Ratio : 24
#
# 'sunflower seed' vs 'Sesame oil'
# Ratio : 25
# Partial Ratio : 24
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Fruit, edible; strawberries, fresh'
# Ratio : 29
# Partial Ratio : 44
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'sunflower seed' vs 'Vegetables, leguminous; chickpeas (garbanzos), shelled, whether or not skinned or split, dried'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'sunflower seed' vs 'Fresh apples'
# Ratio : 31
# Partial Ratio : 33
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Wheat flour'
# Ratio : 32
# Partial Ratio : 47
# Token sort Ratio : 40
# Token set Ratio : 40
#
# 'sunflower seed' vs 'Fresh watermelons'
# Ratio : 32
# Partial Ratio : 44
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sunflower seed' vs 'Fruit, edible; sour cherries (Prunus cerasus), fresh'
# Ratio : 27
# Partial Ratio : 44
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Oil seeds; linseed, whether or not broken'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 42
# Token set Ratio : 42
#
# 'sunflower seed' vs 'Vegetables, leguminous; lentils, shelled, whether or not skinned or split, dried'
# Ratio : 26
# Partial Ratio : 33
# Token sort Ratio : 25
# Token set Ratio : 26
#
# 'sunflower seed' vs 'Fruit, edible; quinces, fresh'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'sunflower seed' vs 'Vegetables, alliaceous; garlic, fresh or chilled'
# Ratio : 26
# Partial Ratio : 33
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'sunflower seed' vs 'Cocoa (whole or broken), raw or roasted'
# Ratio : 30
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 26
#
# 'sunflower seed' vs 'Waxes, other than vegetable, n.e.s. in heading no. 1521; whether or not refined or coloured'
# Ratio : 21
# Partial Ratio : 44
# Token sort Ratio : 20
# Token set Ratio : 21
#
# 'sunflower seed' vs 'Spices, ginger'
# Ratio : 29
# Partial Ratio : 44
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'sunflower seed' vs 'Vegetable roots and tubers; manioc (cassava), with high starch or inulin content, whether or not sliced or in the form of pellets, fresh or dried'
# Ratio : 16
# Partial Ratio : 33
# Token sort Ratio : 18
# Token set Ratio : 19
#
# 'sunflower seed' vs 'Broken rice'
# Ratio : 32
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'sunflower seed' vs 'Coffee; substitutes containing coffee, in any proportion'
# Ratio : 17
# Partial Ratio : 33
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'sunflower seed' vs 'Vegetables; spinach, New Zealand spinach and orache spinach (garden spinach), fresh or chilled'
# Ratio : 20
# Partial Ratio : 33
# Token sort Ratio : 16
# Token set Ratio : 20
#
# 'sunflower seed' vs 'Vegetables; olives, fresh or chilled'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sunflower seed' vs 'Other soybeans, even crushed'
# Ratio : 33
# Partial Ratio : 33
# Token sort Ratio : 39
# Token set Ratio : 39
#
# 'sunflower seed' vs 'Fruit, edible; apricots, fresh'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'sunflower seed' vs 'Cereals, rye'
# Ratio : 31
# Partial Ratio : 22
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sunflower seed' vs 'Food preparations; of flour, meal, starch, malt extract or milk products, for infant use, put up for retail sale'
# Ratio : 16
# Partial Ratio : 44
# Token sort Ratio : 15
# Token set Ratio : 16
#
# 'sunflower seed' vs 'Manioc (cassava) starch'
# Ratio : 22
# Partial Ratio : 22
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sunflower seed' vs 'Live asses, mules and hinnies'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Cereals, grain sorghum'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'sunflower seed' vs 'Oil seeds; cotton seeds, whether or not broken'
# Ratio : 23
# Partial Ratio : 33
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Copra'
# Ratio : 21
# Partial Ratio : 40
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'sunflower seed' vs 'Fresh/chilled/frozen/dried sweet potatoes'
# Ratio : 33
# Partial Ratio : 33
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Fresh/chilled aubergines (egg-plants)'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'sunflower seed' vs 'Fruit, edible; bananas, (including plantains), fresh or dried'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sunflower seed' vs 'Cereals, oats'
# Ratio : 30
# Partial Ratio : 22
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Oil seeds; mustard seeds, whether or not broken'
# Ratio : 26
# Partial Ratio : 33
# Token sort Ratio : 31
# Token set Ratio : 34
#
# 'sunflower seed' vs 'Pears, fresh'
# Ratio : 31
# Partial Ratio : 35
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'sunflower seed' vs 'Fres/chil/froz oth.meat/edib.meat offal of rabib./hares'
# Ratio : 20
# Partial Ratio : 44
# Token sort Ratio : 24
# Token set Ratio : 25
#
# 'sunflower seed' vs 'Cereals, buckwheat'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'sunflower seed' vs 'Meat of goats, fresh, chilled or frozen'
# Ratio : 26
# Partial Ratio : 33
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Fruit, edible; dates, fresh or dried'
# Ratio : 32
# Partial Ratio : 33
# Token sort Ratio : 38
# Token set Ratio : 38
#
# 'sunflower seed' vs 'Nuts, edible; kola nuts (Cola spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 24
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 25
#
# 'sunflower seed' vs 'Goats, live'
# Ratio : 24
# Partial Ratio : 35
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Dairy produce; buttermilk, curdled milk or cream, kephir, fermented or acidified milk or cream, whether or not concentrated or containing added sweetening, flavouring, fruit or cocoa (excluding yoghurt)'
# Ratio : 12
# Partial Ratio : 33
# Token sort Ratio : 12
# Token set Ratio : 13
#
# 'sunflower seed' vs 'Bran and other residues, of rice'
# Ratio : 35
# Partial Ratio : 44
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'sunflower seed' vs 'Fresh/dried pineapples'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 39
# Token set Ratio : 39
#
# 'sunflower seed' vs 'Nuts, edible; pistachios, fresh or dried, whether or not shelled or peeled'
# Ratio : 25
# Partial Ratio : 33
# Token sort Ratio : 26
# Token set Ratio : 28
#
# 'sunflower seed' vs 'Dry grapes'
# Ratio : 25
# Partial Ratio : 11
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'sunflower seed' vs 'Butter, fat and oil, from cocoa'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'sunflower seed' vs 'Nuts, edible; coconuts, fresh or dried, whether or not shelled or peeled'
# Ratio : 28
# Partial Ratio : 33
# Token sort Ratio : 27
# Token set Ratio : 29
#
# 'sunflower seed' vs 'Sauces, soya'
# Ratio : 31
# Partial Ratio : 22
# Token sort Ratio : 40
# Token set Ratio : 40
#
# 'sunflower seed' vs 'Fresh papaws (papayas)'
# Ratio : 22
# Partial Ratio : 22
# Token sort Ratio : 18
# Token set Ratio : 18
#
# 'sunflower seed' vs 'Sheep, live'
# Ratio : 24
# Partial Ratio : 24
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'sunflower seed' vs 'Fruit, edible; cranberries, bilberries and other fruits of the genus vaccinium, fresh'
# Ratio : 20
# Partial Ratio : 44
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'sunflower seed' vs 'Spices; cloves (whole fruit, cloves and stems)'
# Ratio : 30
# Partial Ratio : 44
# Token sort Ratio : 25
# Token set Ratio : 24
#
# 'sunflower seed' vs 'Fresh/chilled lettuce'
# Ratio : 34
# Partial Ratio : 33
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'sunflower seed' vs 'Jute and other textile bast fibres; processed but not spun, tow and waste of these fibres, including yarn waste and garnetted stock (excluding flax, hemp (cannabis sativa L.), and ramie)'
# Ratio : 13
# Partial Ratio : 33
# Token sort Ratio : 14
# Token set Ratio : 16
#
# 'sunflower seed' vs 'Cereals, fonio (Digitaria spp.)'
# Ratio : 27
# Partial Ratio : 33
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'sunflower seed' vs 'Vegetable roots and tubers; taro (Colocasia spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 14
# Partial Ratio : 33
# Token sort Ratio : 16
# Token set Ratio : 17
#
# 'sunflower seed' vs 'Fruit, edible; raspberries, blackberries, mulberries and loganberries, fresh'
# Ratio : 20
# Partial Ratio : 44
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'sunflower seed' vs 'Sugar cane; fit for human consumption, fresh, chilled, frozen or dried, whether or not ground'
# Ratio : 22
# Partial Ratio : 33
# Token sort Ratio : 24
# Token set Ratio : 24
#
# ...
# Ratio : 23
# Partial Ratio : 40
# Token sort Ratio : 29
# Token set Ratio : 32
#
# 'oleic acid' vs 'Ploughs'
# Ratio : 12
# Partial Ratio : 20
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'oleic acid' vs 'Vegetables, leguminous; pigeon peas (Cajanus cajan), shelled, whether or not skinned or split, dried'
# Ratio : 15
# Partial Ratio : 40
# Token sort Ratio : 17
# Token set Ratio : 18
#
# 'oleic acid' vs 'Mate'
# Ratio : 14
# Partial Ratio : 25
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'oleic acid' vs 'Maize (corn) starch'
# Ratio : 34
# Partial Ratio : 40
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'oleic acid' vs 'Fish; smoked (whether or not cooked before or during the smoking process), n.e.s. in item no. 0305.4 (including fillets)'
# Ratio : 11
# Partial Ratio : 40
# Token sort Ratio : 11
# Token set Ratio : 12
#
# 'oleic acid' vs 'Fresh/dried grapefruit'
# Ratio : 31
# Partial Ratio : 20
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'oleic acid' vs 'Dairy produce, butter and other fats and oils derived from milk'
# Ratio : 16
# Partial Ratio : 40
# Token sort Ratio : 22
# Token set Ratio : 24
#
# 'oleic acid' vs 'Oleic acid (industrial monocarboxylic fatty acids)'
# Ratio : 30
# Partial Ratio : 80
# Token sort Ratio : 34
# Token set Ratio : 100
#
# 'disc harrows' vs 'Cereals, barley'
# Ratio : 30
# Partial Ratio : 25
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'disc harrows' vs 'Other fresh or chilled potatoes'
# Ratio : 28
# Partial Ratio : 25
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'disc harrows' vs 'Fruit, edible; cherries, fresh'
# Ratio : 33
# Partial Ratio : 50
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Bran, sharps and other residues, of maize'
# Ratio : 23
# Partial Ratio : 25
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'disc harrows' vs 'Cereals, millet'
# Ratio : 15
# Partial Ratio : 25
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'disc harrows' vs 'Oil seeds; sesamum seeds, whether or not broken'
# Ratio : 24
# Partial Ratio : 25
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'disc harrows' vs 'Cigarettes containing tobacco'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'disc harrows' vs 'Tomato, fresh or chilled'
# Ratio : 17
# Partial Ratio : 25
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'disc harrows' vs 'Pulp, bagasse and other waste of sugar manufacture'
# Ratio : 19
# Partial Ratio : 25
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'disc harrows' vs 'Oil seeds; sunflower seeds, whether or not broken'
# Ratio : 23
# Partial Ratio : 25
# Token sort Ratio : 17
# Token set Ratio : 19
#
# 'disc harrows' vs 'Fruit, edible; figs, fresh or dried'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'disc harrows' vs 'Bran, sharps and other residues; of wheat, whether or not in the form of pellets, derived from the sifting, milling or other workings thereof'
# Ratio : 14
# Partial Ratio : 25
# Token sort Ratio : 15
# Token set Ratio : 17
#
# 'disc harrows' vs 'Bananas-of-the-earth, fresh or dried'
# Ratio : 25
# Partial Ratio : 50
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'disc harrows' vs 'Maize (corn) flour'
# Ratio : 27
# Partial Ratio : 25
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'disc harrows' vs 'Dairy produce; cheese, processed (not grated or powdered)'
# Ratio : 23
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'disc harrows' vs 'Fresh or chilled asparagus'
# Ratio : 32
# Partial Ratio : 50
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Fresh/dried avocados'
# Ratio : 38
# Partial Ratio : 50
# Token sort Ratio : 38
# Token set Ratio : 38
#
# 'disc harrows' vs 'Pig fat; lard, other than that of heading 0209 and 1503'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 18
#
# 'disc harrows' vs 'Oil seeds; poppy seeds, whether or not broken'
# Ratio : 25
# Partial Ratio : 25
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'disc harrows' vs 'Grape juice, unfermented'
# Ratio : 22
# Partial Ratio : 50
# Token sort Ratio : 23
# Token set Ratio : 23
#
# 'disc harrows' vs 'Asses, live'
# Ratio : 17
# Partial Ratio : 25
# Token sort Ratio : 18
# Token set Ratio : 18
#
# 'disc harrows' vs 'Nuts, edible; chestnuts (castanea spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 20
# Partial Ratio : 50
# Token sort Ratio : 17
# Token set Ratio : 16
#
# 'disc harrows' vs 'Sesame oil'
# Ratio : 27
# Partial Ratio : 25
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'disc harrows' vs 'Fruit, edible; strawberries, fresh'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 37
# Token set Ratio : 37
#
# 'disc harrows' vs 'Vegetables, leguminous; chickpeas (garbanzos), shelled, whether or not skinned or split, dried'
# Ratio : 17
# Partial Ratio : 25
# Token sort Ratio : 16
# Token set Ratio : 15
#
# 'disc harrows' vs 'Fresh apples'
# Ratio : 33
# Partial Ratio : 25
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'disc harrows' vs 'Wheat flour'
# Ratio : 26
# Partial Ratio : 0
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Fresh watermelons'
# Ratio : 41
# Partial Ratio : 25
# Token sort Ratio : 41
# Token set Ratio : 41
#
# 'disc harrows' vs 'Fruit, edible; sour cherries (Prunus cerasus), fresh'
# Ratio : 25
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'disc harrows' vs 'Oil seeds; linseed, whether or not broken'
# Ratio : 30
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'disc harrows' vs 'Vegetables, leguminous; lentils, shelled, whether or not skinned or split, dried'
# Ratio : 17
# Partial Ratio : 25
# Token sort Ratio : 16
# Token set Ratio : 17
#
# 'disc harrows' vs 'Fruit, edible; quinces, fresh'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'disc harrows' vs 'Vegetables, alliaceous; garlic, fresh or chilled'
# Ratio : 23
# Partial Ratio : 50
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'disc harrows' vs 'Cocoa (whole or broken), raw or roasted'
# Ratio : 31
# Partial Ratio : 25
# Token sort Ratio : 25
# Token set Ratio : 27
#
# 'disc harrows' vs 'Waxes, other than vegetable, n.e.s. in heading no. 1521; whether or not refined or coloured'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 17
#
# 'disc harrows' vs 'Spices, ginger'
# Ratio : 31
# Partial Ratio : 50
# Token sort Ratio : 32
# Token set Ratio : 32
#
# 'disc harrows' vs 'Vegetable roots and tubers; manioc (cassava), with high starch or inulin content, whether or not sliced or in the form of pellets, fresh or dried'
# Ratio : 14
# Partial Ratio : 50
# Token sort Ratio : 13
# Token set Ratio : 14
#
# 'disc harrows' vs 'Broken rice'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 17
# Token set Ratio : 17
#
# 'disc harrows' vs 'Coffee; substitutes containing coffee, in any proportion'
# Ratio : 24
# Partial Ratio : 50
# Token sort Ratio : 21
# Token set Ratio : 24
#
# 'disc harrows' vs 'Vegetables; spinach, New Zealand spinach and orache spinach (garden spinach), fresh or chilled'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 23
#
# 'disc harrows' vs 'Vegetables; olives, fresh or chilled'
# Ratio : 21
# Partial Ratio : 25
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Other soybeans, even crushed'
# Ratio : 20
# Partial Ratio : 25
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'disc harrows' vs 'Fruit, edible; apricots, fresh'
# Ratio : 33
# Partial Ratio : 50
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Cereals, rye'
# Ratio : 25
# Partial Ratio : 25
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Food preparations; of flour, meal, starch, malt extract or milk products, for infant use, put up for retail sale'
# Ratio : 16
# Partial Ratio : 25
# Token sort Ratio : 14
# Token set Ratio : 14
#
# 'disc harrows' vs 'Manioc (cassava) starch'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'disc harrows' vs 'Live asses, mules and hinnies'
# Ratio : 24
# Partial Ratio : 50
# Token sort Ratio : 25
# Token set Ratio : 25
#
# 'disc harrows' vs 'Cereals, grain sorghum'
# Ratio : 24
# Partial Ratio : 25
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'disc harrows' vs 'Oil seeds; cotton seeds, whether or not broken'
# Ratio : 28
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'disc harrows' vs 'Copra'
# Ratio : 12
# Partial Ratio : 0
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'disc harrows' vs 'Fresh/chilled/frozen/dried sweet potatoes'
# Ratio : 26
# Partial Ratio : 50
# Token sort Ratio : 26
# Token set Ratio : 26
#
# 'disc harrows' vs 'Fresh/chilled aubergines (egg-plants)'
# Ratio : 24
# Partial Ratio : 25
# Token sort Ratio : 30
# Token set Ratio : 30
#
# 'disc harrows' vs 'Fruit, edible; bananas, (including plantains), fresh or dried'
# Ratio : 22
# Partial Ratio : 50
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'disc harrows' vs 'Cereals, oats'
# Ratio : 32
# Partial Ratio : 25
# Token sort Ratio : 33
# Token set Ratio : 33
#
# 'disc harrows' vs 'Oil seeds; mustard seeds, whether or not broken'
# Ratio : 24
# Partial Ratio : 25
# Token sort Ratio : 21
# Token set Ratio : 24
#
# 'disc harrows' vs 'Pears, fresh'
# Ratio : 33
# Partial Ratio : 25
# Token sort Ratio : 43
# Token set Ratio : 43
#
# 'disc harrows' vs 'Fres/chil/froz oth.meat/edib.meat offal of rabib./hares'
# Ratio : 24
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 26
#
# 'disc harrows' vs 'Cereals, buckwheat'
# Ratio : 27
# Partial Ratio : 25
# Token sort Ratio : 34
# Token set Ratio : 34
#
# 'disc harrows' vs 'Meat of goats, fresh, chilled or frozen'
# Ratio : 24
# Partial Ratio : 25
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'disc harrows' vs 'Fruit, edible; dates, fresh or dried'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'disc harrows' vs 'Nuts, edible; kola nuts (Cola spp.), fresh or dried, whether or not shelled or peeled'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 18
#
# 'disc harrows' vs 'Goats, live'
# Ratio : 17
# Partial Ratio : 25
# Token sort Ratio : 18
# Token set Ratio : 18
#
# 'disc harrows' vs 'Dairy produce; buttermilk, curdled milk or cream, kephir, fermented or acidified milk or cream, whether or not concentrated or containing added sweetening, flavouring, fruit or cocoa (excluding yoghurt)'
# Ratio : 9
# Partial Ratio : 50
# Token sort Ratio : 9
# Token set Ratio : 10
#
# 'disc harrows' vs 'Bran and other residues, of rice'
# Ratio : 27
# Partial Ratio : 50
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'disc harrows' vs 'Fresh/dried pineapples'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'disc harrows' vs 'Nuts, edible; pistachios, fresh or dried, whether or not shelled or peeled'
# Ratio : 23
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 18
#
# 'disc harrows' vs 'Dry grapes'
# Ratio : 27
# Partial Ratio : 25
# Token sort Ratio : 36
# Token set Ratio : 36
#
# 'disc harrows' vs 'Butter, fat and oil, from cocoa'
# Ratio : 23
# Partial Ratio : 50
# Token sort Ratio : 29
# Token set Ratio : 29
#
# 'disc harrows' vs 'Nuts, edible; coconuts, fresh or dried, whether or not shelled or peeled'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 20
# Token set Ratio : 16
#
# 'disc harrows' vs 'Sauces, soya'
# Ratio : 25
# Partial Ratio : 25
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'disc harrows' vs 'Fresh papaws (papayas)'
# Ratio : 29
# Partial Ratio : 25
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'disc harrows' vs 'Sheep, live'
# Ratio : 9
# Partial Ratio : 25
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'disc harrows' vs 'Fruit, edible; cranberries, bilberries and other fruits of the genus vaccinium, fresh'
# Ratio : 19
# Partial Ratio : 50
# Token sort Ratio : 19
# Token set Ratio : 19
#
# 'disc harrows' vs 'Spices; cloves (whole fruit, cloves and stems)'
# Ratio : 28
# Partial Ratio : 50
# Token sort Ratio : 26
# Token set Ratio : 30
#
# 'disc harrows' vs 'Fresh/chilled lettuce'
# Ratio : 18
# Partial Ratio : 50
# Token sort Ratio : 24
# Token set Ratio : 24
#
# 'disc harrows' vs 'Jute and other textile bast fibres; processed but not spun, tow and waste of these fibres, including yarn waste and garnetted stock (excluding flax, hemp (cannabis sativa L.), and ramie)'
# Ratio : 11
# Partial Ratio : 25
# Token sort Ratio : 12
# Token set Ratio : 13
#
# 'disc harrows' vs 'Cereals, fonio (Digitaria spp.)'
# Ratio : 23
# Partial Ratio : 25
# Token sort Ratio : 31
# Token set Ratio : 31
#
# 'disc harrows' vs 'Vegetable roots and tubers; taro (Colocasia spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 13
# Token set Ratio : 14
#
# 'disc harrows' vs 'Fruit, edible; raspberries, blackberries, mulberries and loganberries, fresh'
# Ratio : 20
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 22
#
# 'disc harrows' vs 'Sugar cane; fit for human consumption, fresh, chilled, frozen or dried, whether or not ground'
# Ratio : 15
# Partial Ratio : 25
# Token sort Ratio : 18
# Token set Ratio : 19
#
# 'disc harrows' vs 'Meat and edible meat offal; of camels and other camelids (Camelidae), fresh, chilled or frozen'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 18
# Token set Ratio : 20
#
# 'disc harrows' vs 'Vegetable roots and tubers; yams (Dioscorea spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 13
# Partial Ratio : 75
# Token sort Ratio : 13
# Token set Ratio : 14
#
# 'disc harrows' vs 'Oil seeds; safflower seeds, whether or not broken'
# Ratio : 23
# Partial Ratio : 25
# Token sort Ratio : 20
# Token set Ratio : 23
#
# 'disc harrows' vs 'Oleaginous fruits; palm nuts and kernels, whether or not broken'
# Ratio : 19
# Partial Ratio : 25
# Token sort Ratio : 19
# Token set Ratio : 19
#
# 'disc harrows' vs 'Molluscs; snails (other than sea snails), live, fresh, chilled, frozen, dried, salted or in brine (whether in shell or not)'
# Ratio : 15
# Partial Ratio : 25
# Token sort Ratio : 15
# Token set Ratio : 14
#
# 'disc harrows' vs 'Yoghurt'
# Ratio : 21
# Partial Ratio : 0
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'disc harrows' vs 'Cereals, quinoa (Chenopodium quinoa)'
# Ratio : 17
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 21
#
# 'disc harrows' vs 'Vegetable roots and tubers; yautia (Xanthosoma spp.) with high starch or inulin content, fresh, chilled, frozen or dried, whether or not sliced or in the form of pellets'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'disc harrows' vs 'locust beans, seaweeds and other algae, sugar beet and sugar cane, fresh, chilled, frozen or dried, whether or not ground; fruit stones and kernels and other vegetable products (including unroasted chicory roots of the variety cichorium intybus sativum) of a kind used primarily for human consumption, not elsewhere specified or included; seaweeds and other algae other than fit for human consumption'
# Ratio : 6
# Partial Ratio : 50
# Token sort Ratio : 6
# Token set Ratio : 8
#
# 'disc harrows' vs 'Oleaginous fruits, shea nuts (karite nuts)'
# Ratio : 26
# Partial Ratio : 25
# Token sort Ratio : 27
# Token set Ratio : 30
#
# 'disc harrows' vs 'Ploughs'
# Ratio : 21
# Partial Ratio : 25
# Token sort Ratio : 21
# Token set Ratio : 21
#
# 'disc harrows' vs 'Vegetables, leguminous; pigeon peas (Cajanus cajan), shelled, whether or not skinned or split, dried'
# Ratio : 16
# Partial Ratio : 25
# Token sort Ratio : 15
# Token set Ratio : 14
#
# 'disc harrows' vs 'Mate'
# Ratio : 12
# Partial Ratio : 0
# Token sort Ratio : 12
# Token set Ratio : 12
#
# 'disc harrows' vs 'Maize (corn) starch'
# Ratio : 32
# Partial Ratio : 25
# Token sort Ratio : 28
# Token set Ratio : 28
#
# 'disc harrows' vs 'Fish; smoked (whether or not cooked before or during the smoking process), n.e.s. in item no. 0305.4 (including fillets)'
# Ratio : 12
# Partial Ratio : 25
# Token sort Ratio : 15
# Token set Ratio : 15
#
# 'disc harrows' vs 'Fresh/dried grapefruit'
# Ratio : 29
# Partial Ratio : 50
# Token sort Ratio : 35
# Token set Ratio : 35
#
# 'disc harrows' vs 'Dairy produce, butter and other fats and oils derived from milk'
# Ratio : 21
# Partial Ratio : 50
# Token sort Ratio : 22
# Token set Ratio : 23
#
# 'disc harrows' vs 'Oleic acid (industrial monocarboxylic fatty acids)'
# Ratio : 26
# Partial Ratio : 50
# Token sort Ratio : 27
# Token set Ratio : 27
#
# 'disc harrows' vs 'Disc harrows, used agricultural, etc.f/soil preparation'
# Ratio : 33
# Partial Ratio : 50
# Token sort Ratio : 37
# Token set Ratio : 100
