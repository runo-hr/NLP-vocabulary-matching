# %% [markdown]
# # NLP Vocabulary matching
# [GitHUb repo](https://github.com/runo-hr/NLP-vocabulary-matching)
#
# This notebook outlines the process of matching similar agricultural commodities from two different sources.

# %% [markdown]
# ## Importing Libraries

# %%
#! pip install thefuzz
#! pip install python-Levenshtein

# %%
import pandas as pd
from thefuzz import fuzz, process

# %%
import sys
# The recursion limit is 10 ** 3. The input data is in the magnitude of 10 ** 4.
# The matching algorithm will be recursive.
sys.setrecursionlimit(10**6)

# %% [markdown]
# ## Understanding the Data

# %%
df1 = pd.read_csv('source_1.csv')
df2 = pd.read_csv('source_2.csv')

print(f'Shape of source_1 : {df1.shape}')
print(f'Shape of source_2 : {df2.shape}')
# Out:
# Shape of source_1 : (13238, 2)
# Shape of source_2 : (48943, 2)

# %%
df1.head()
# Out:
#    id                                               name
# 0   0  Horses, asses, mules and hinnies; live, pure-b...
# 1   1           Horses; live, pure-bred breeding animals
# 2   2  Horses; live, other than pure-bred breeding an...
# 3   4  Horses, asses, mules and hinnies; live, other ...
# 4   5   Bovine animals; live, pure-bred breeding animals

# %%
df2.head()
# Out:
#    id                            name
# 0   0   leveillula lactucae-serriolae
# 1   1             podosphaera aphanis
# 2   2          lathyrus czeczottianus
# 3   3  crocus biflorus subsp. caricus
# 4   4          hordeum brevisubulatum

# %%
df1 = df1[['id', 'name']].set_index('name')
df1.index.name = None
s1_dict = df1.to_dict()['id']

df2 = df2[['id', 'name']].set_index('name')
df2.index.name = None
s2_dict = df2.to_dict()['id']

print(f"There are {len(s1_dict)} unique commodities in the first source. {len(df1) - len(s1_dict)} were duplicates.")
print(f"There are {len(s2_dict)} unique commodities in the second source. {len(df2) - len(s2_dict)} were duplicates.")
# Out:
# There are 12582 unique commodities in the first source. 656 were duplicates.
# There are 48874 unique commodities in the second source. 69 were duplicates.

# %% [markdown]
# ### Insights
# * Source_1 entries are generally longer than source_2.
# * There were 12582 unique entries in source_1 and 48874 entries in source_2.
#
# ### New data
# * df1: Source 1 dataframe, df2: source 2 dataframe.
# * s1_dict and s2_dict are name-id dictionaries of commodities from the two sources

# %% [markdown]
# The code cells below create input lists for the matching algorithm.
# The jupyter kernel failed before processing all the entries. To rerun the matching algorithm, I removed the already matched examples from the input list.

# %%
df_old_matches = pd.read_csv('matched_names_ids.csv')
df_old_matches.head()

# %%
df1_old = df_old_matches[['id1', 'source_1']].set_index('source_1')
df1_old_dict = df1_old.to_dict()['id1']

df2_old = df_old_matches[['id2', 'source_2']].set_index('source_2')
df2_old_dict = df2_old.to_dict()['id2']

# %%
df1.index.to_list()[:10]

# %%
s1 = []
for entry in df1.index.to_list():
    try:
        df1_old_dict[entry]
    except KeyError:
        s1.append(entry)
#s1

# %%
df2.index.to_list()[:10]

# %%
s2 = []
for entry in df2.index.to_list():
    try:
        df2_old_dict[entry]
    except KeyError:
        s2.append(entry)
#s2

# %% [markdown]
# ## Matching algorithm
# The algorithm uses the extractOne method from the fuzz class of thefuzz library.
# extractOne gets the best match of a string in a list of strings.
# The scorer parameter is passed to tune the results of best match.
# Below, I used the partial_token_sort_ratio as the scorer. I found it to give the best matches for this task.
#
# Other scorers include:
# * partial_token_sort_ratio (used below)
# * partial_token_set_ratio
# * token_sort_ratio
# * token_set_ratio
# * partial_ratio
# * ratio
#
# More on fuzzy string matching [here](https://youtu.be/1jNNde4k9Ng).

# %%
# lists to create pandas dataframes
matched_ids = []
matched_names_ids = []

def closest_matches(src1:list, src2:list, names_id_src1:dict, names_id_src2:dict):
    '''
        Parameters
        src1:list, src2:list, 
        names_id_src1:dict, names_id_src2:dict
        
        return
        matched_ids:list,  matched_names_ids:list
    '''
    # save unprocessed inputs to csv incase the runtime disconnects
    s1_df = pd.DataFrame(src1)
    s1_df.to_csv('remaininder_s1.csv')

    s2_df = pd.DataFrame(src2)
    s2_df.to_csv('remaininder_s2.csv')
    
    # base case of recursion
    # source 1 has fewer entries than source 2
    if len(src1) == 0:
        return matched_ids, matched_names_ids
    
    for item in src1:
        best_match = process.extractOne(item, src2, scorer=fuzz.partial_token_sort_ratio)
        confidence = best_match[1] # confidence of the match
        
        if confidence == 100: # good match
            src1_item_id = names_id_src1[item] # get item id

            src2_item = best_match[0] # get source 2 item
            src2_item_id = names_id_src2[src2_item] # source 2 item id

            # save matched ids to csv
            matched_ids.append(dict(source_1=src1_item_id, source_2=src2_item_id))
            df_ids = pd.DataFrame(matched_ids)
            df_ids.to_csv('predicted_ids.csv')

            # save matched ids and names to csv
            matched_names_ids.append(dict(id1=src1_item_id, source_1=item, id2=src2_item_id,source_2=src2_item))
            df_names_ids = pd.DataFrame(matched_names_ids)
            df_names_ids.to_csv('predicted_names_ids.csv')

            # remove found matches from input lists
            src1.remove(item)
            src2.remove(src2_item)

            print(df_names_ids)
            print()
            return closest_matches(src1, src2, names_id_src1, names_id_src2)
        else: # no good match found
            src1.remove(item)
            return closest_matches(src1, src2, names_id_src1, names_id_src2)

# %%
len(s1), len(s2), len(s1_dict), len(s2_dict)

# %%
ids_matched, names_ids_matched = closest_matches(s1, s2, s1_dict, s2_dict)

# %% [markdown]
# ## Further Processing
# Some predicted matches were wrong.
# The cells below go through every found match and determine the token_set_ratio.
# Matches with less than 100 are discarded.

# %%
def get_ratios(i, j):
    print(f"'{i}' vs '{j}'")

    ratio = fuzz.ratio(i, j)
    print(f"Ratio : {ratio}")

    partial_ratio = fuzz.partial_ratio(i, j)
    print(f"Partial Ratio : {partial_ratio}")

    token_sort_ratio = fuzz.token_sort_ratio(i, j)
    print(f"Token sort Ratio : {token_sort_ratio}")

    token_set_ratio = fuzz.token_set_ratio(i, j)
    print(f"Token set Ratio : {token_set_ratio}")

    partial_token_sort_ratio = fuzz.partial_token_sort_ratio(i, j)
    print(f"Partial token sort Ratio : {partial_token_sort_ratio}")

    partial_token_set_ratio = fuzz.partial_token_set_ratio(i, j)
    print(f"Partial token set Ratio : {partial_token_set_ratio}")
    print()


    return partial_ratio, token_set_ratio

# %%
#df_matched = pd.read_csv('matched_names_ids.csv')
df_matched = pd.read_csv('predicted_names_ids3.csv')
df_matched.shape
# Out:
# (94, 5)

# %%
df_matched
# Out:
#     Unnamed: 0    id1                                           source_1  \
# 0            0  11198                                       Dynamometers
# 1            1  11199                 Surface-finish testing instruments
# 2            2  11200  Machines for taking three-dimensional measurem...
# 3            3  11209                              Artificial honeycombs
# 4            4  11219                       Hand sieves and hand riddles
# ..         ...    ...                                                ...
# 89          89  12129                   Appliances known as iron lungs
# 90          90  12130  Ozone therapy apparatus and oth.of therapeutic...
# 91          91  12141  Reception appar.personal of radium-mes.in scre...
# 92          92  12183                         Electronic microassemblies
# 93          93  12188  Ion implanters for doping semiconductor materials
#
#       id2      source_2
# 0    8946  dynamometers
# 1   42547       testing
# 2   32546   measurement
# 3   21116    honeycombs
# 4   11728        sieves
# ..    ...           ...
# 89  30164         lungs
# 90  37661         ozone
# 91  39826        radium
# 92  36565    assemblies
# 93   7013        doping
#
# [94 rows x 5 columns]

# %%
s1 = df_matched.source_1.to_list()
s2 = df_matched.source_2.to_list()

# %%
len(s1_dict), len(s2_dict)
# Out:
# (12582, 48874)

# %%
processed_ids = []
processed_names_ids = []
for x,y in zip(s1, s2):
    partial_ratio, token_set_ratio = get_ratios(x,y)
    if (token_set_ratio < 90 and partial_ratio < 80) :
        continue
    else:
        id1 = s1_dict[x]
        id2 = s2_dict[y]
        
        processed_ids.append(dict(source_1=id1, source_2=id2))
        df_processed_ids = pd.DataFrame(processed_ids)
        df_processed_ids.to_csv('processed_ids3.csv')
            
        processed_names_ids.append(dict(id_1=id1, source_1=x, id_2=id2, source_2=y))
        df_processed_names_ids = pd.DataFrame(processed_names_ids)
        df_processed_names_ids.to_csv('processed_names_ids3.csv')
# Out:
# 'Dynamometers' vs 'dynamometers'
# Ratio : 92
# Partial Ratio : 92
# Token sort Ratio : 100
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Surface-finish testing instruments' vs 'testing'
# Ratio : 34
# Partial Ratio : 100
# Token sort Ratio : 34
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Machines for taking three-dimensional measurements' vs 'measurement'
# Ratio : 36
# Partial Ratio : 100
# Token sort Ratio : 36
# Token set Ratio : 36
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Artificial honeycombs' vs 'honeycombs'
# Ratio : 65
# Partial Ratio : 100
# Token sort Ratio : 65
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Hand sieves and hand riddles' vs 'sieves'
# Ratio : 35
# Partial Ratio : 100
# Token sort Ratio : 35
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Autom.electronic controllers f/anti-lock braking syst.' vs 'raking'
# Ratio : 20
# Partial Ratio : 100
# Token sort Ratio : 20
# Token set Ratio : 20
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Autom.electronic controllers f/suspension systems' vs 'suspension systems'
# Ratio : 54
# Partial Ratio : 100
# Token sort Ratio : 54
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Duplicating stylos,pencil-holders and similar articles' vs 'stylos'
# Ratio : 20
# Partial Ratio : 100
# Token sort Ratio : 20
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Pastels,draw.charc.writing/drawing chalks and tailors'' vs 'chalk'
# Ratio : 17
# Partial Ratio : 100
# Token sort Ratio : 17
# Token set Ratio : 17
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Autom.instruments and apparatus f/checking temperature' vs 'temperature'
# Ratio : 34
# Partial Ratio : 100
# Token sort Ratio : 34
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Autom.instruments and apparatus f/checking humidity' vs 'humidity'
# Ratio : 27
# Partial Ratio : 100
# Token sort Ratio : 27
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other meat of chickens and hens' vs 'chickens'
# Ratio : 41
# Partial Ratio : 100
# Token sort Ratio : 41
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Anonyas and others fruits of genero Annona' vs 'annona'
# Ratio : 25
# Partial Ratio : 83
# Token sort Ratio : 25
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Pitaias (Hylocereus spp., Selenicereus undatus)' vs 'hylocereus'
# Ratio : 32
# Partial Ratio : 90
# Token sort Ratio : 38
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other articles and prostheses apparatus' vs 'prostheses'
# Ratio : 41
# Partial Ratio : 100
# Token sort Ratio : 41
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Intra-ocular lenses' vs 'lens'
# Ratio : 35
# Partial Ratio : 100
# Token sort Ratio : 35
# Token set Ratio : 35
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Non-implantable artificial breasts' vs 'breasts'
# Ratio : 34
# Partial Ratio : 100
# Token sort Ratio : 34
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Parts for the upper or lower artificial limbs' vs 'limbs'
# Ratio : 20
# Partial Ratio : 100
# Token sort Ratio : 20
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Pacemakers f/stimulating heart muscles,excl.parts/acces' vs 'heart muscle'
# Ratio : 36
# Partial Ratio : 100
# Token sort Ratio : 36
# Token set Ratio : 59
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Automatic cardiac defibrillators' vs 'brill'
# Ratio : 27
# Partial Ratio : 100
# Token sort Ratio : 27
# Token set Ratio : 27
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Oth.apparatus f/compensating deficiencies/illnesses' vs 'deficiencies'
# Ratio : 38
# Partial Ratio : 100
# Token sort Ratio : 38
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Yokes for watch apparatus' vs 'yokes'
# Ratio : 27
# Partial Ratio : 80
# Token sort Ratio : 33
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Carambolas (Averrhoa carambola)' vs 'averrhoa'
# Ratio : 41
# Partial Ratio : 88
# Token sort Ratio : 43
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Jacas (Artocarpus heterophyllus)' vs 'artocarpus'
# Ratio : 48
# Partial Ratio : 90
# Token sort Ratio : 50
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Lechias (Litchi chinensis)' vs 'litchi'
# Ratio : 31
# Partial Ratio : 83
# Token sort Ratio : 40
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Maracujás (Passiflora edulis)' vs 'passiflora'
# Ratio : 46
# Partial Ratio : 90
# Token sort Ratio : 56
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Tamarindos (Tamarindus indica)' vs 'tamarindus'
# Ratio : 45
# Partial Ratio : 90
# Token sort Ratio : 53
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Purês de cupuaçu (Theobroma grandiflorum)' vs 'theobroma'
# Ratio : 32
# Partial Ratio : 89
# Token sort Ratio : 39
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Água de coco (Cocos nucifera) com valor Brix não superior a 7,4' vs 'cocos'
# Ratio : 15
# Partial Ratio : 80
# Token sort Ratio : 16
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Reciprocat.posit.displacement pumps, 5hp<potency<=600hp' vs 'placement'
# Ratio : 28
# Partial Ratio : 100
# Token sort Ratio : 29
# Token set Ratio : 29
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other reciprocating positive displacement pumps' vs 'displacement'
# Ratio : 41
# Partial Ratio : 100
# Token sort Ratio : 41
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Piledrivers and pile-extractors' vs 'extractors'
# Ratio : 49
# Partial Ratio : 100
# Token sort Ratio : 49
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Mach.f/perforat.of tunnels and galleries, self-propelled' vs 'tunnels'
# Ratio : 22
# Partial Ratio : 100
# Token sort Ratio : 23
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Hooks and rings, of cast iron/iron/steel' vs 'hooks'
# Ratio : 18
# Partial Ratio : 80
# Token sort Ratio : 23
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Pneumatic conveyors mobile appar.with engines>120hp' vs 'conveyors'
# Ratio : 30
# Partial Ratio : 100
# Token sort Ratio : 30
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other pneumatic elevators and conveyors' vs 'elevators'
# Ratio : 38
# Partial Ratio : 100
# Token sort Ratio : 38
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Machin.elevators/conveyors of goods, chain type' vs 'chain conveyors'
# Ratio : 42
# Partial Ratio : 67
# Token sort Ratio : 49
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Machinery for disembarkation of lifeboats, etc' vs 'lifeboats'
# Ratio : 33
# Partial Ratio : 100
# Token sort Ratio : 33
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Barbed wire of other iron or steel, used f/fencing' vs 'fencing'
# Ratio : 25
# Partial Ratio : 100
# Token sort Ratio : 25
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Mach.sprayin.press.butt.f/project.liquid/powders, foams' vs 'foams'
# Ratio : 17
# Partial Ratio : 100
# Token sort Ratio : 17
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Parts of fire extinguis./mach.f/spraying, etc.hand oper.' vs 'spraying'
# Ratio : 25
# Partial Ratio : 100
# Token sort Ratio : 26
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Protocol analysers,for telecommunications' vs 'telecommunications'
# Ratio : 61
# Partial Ratio : 100
# Token sort Ratio : 61
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Electr.trains of toy.incl.tracks/signals/acces.therefor' vs 'signals'
# Ratio : 23
# Partial Ratio : 100
# Token sort Ratio : 23
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other toys and models,incorporating a motor,electric' vs 'models'
# Ratio : 21
# Partial Ratio : 100
# Token sort Ratio : 21
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Parts and acces.f/measur.appar.etc.ionising radiations' vs 'radiation'
# Ratio : 29
# Partial Ratio : 100
# Token sort Ratio : 29
# Token set Ratio : 29
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Video games used with a television receiver' vs 'television'
# Ratio : 38
# Partial Ratio : 100
# Token sort Ratio : 38
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Shredding machinery for cotton' vs 'redd+'
# Ratio : 23
# Partial Ratio : 80
# Token sort Ratio : 24
# Token set Ratio : 24
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Unrefined copper  and anodes cop.f/electr.refining' vs 'refining'
# Ratio : 28
# Partial Ratio : 100
# Token sort Ratio : 28
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Oth.drawing marking-out or mathemat.calcul.intruments' vs 'marking'
# Ratio : 23
# Partial Ratio : 100
# Token sort Ratio : 23
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other appar. of eletrodiag. by ultrasonic scanning' vs 'canning'
# Ratio : 25
# Partial Ratio : 100
# Token sort Ratio : 25
# Token set Ratio : 25
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Magnetic resonance imaging apparatus' vs 'aging'
# Ratio : 24
# Partial Ratio : 60
# Token sort Ratio : 24
# Token set Ratio : 24
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Scent sprays and sim.toilet spr.mounts and heads ther.' vs 'prays'
# Ratio : 17
# Partial Ratio : 100
# Token sort Ratio : 17
# Token set Ratio : 19
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Collections and collectors' pieces of zoolog.botan.etc.' vs 'collection'
# Ratio : 31
# Partial Ratio : 80
# Token sort Ratio : 32
# Token set Ratio : 32
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Goods in devolution' vs 'evolution'
# Ratio : 64
# Partial Ratio : 100
# Token sort Ratio : 64
# Token set Ratio : 64
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Oth.recep.appar.radio-broadcasting  by pile/electr.etc.' vs 'broadcasting'
# Ratio : 36
# Partial Ratio : 100
# Token sort Ratio : 37
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Circuit obtain.bipolar technology,not mounted' vs 'technology'
# Ratio : 36
# Partial Ratio : 100
# Token sort Ratio : 36
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Parts/access.of pacemakers f/stimulating heart muscles' vs 'muscles'
# Ratio : 23
# Partial Ratio : 100
# Token sort Ratio : 23
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Tomography apparatus, program controlled' vs 'tomography'
# Ratio : 36
# Partial Ratio : 90
# Token sort Ratio : 41
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Apparatus of x-rays,for diagnostic angiography' vs 'angiography'
# Ratio : 39
# Partial Ratio : 100
# Token sort Ratio : 39
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Oth.appar.of x-rays,f/radiography or radiotherapy' vs 'radiotherapy'
# Ratio : 39
# Partial Ratio : 100
# Token sort Ratio : 39
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Caprylic acid' vs 'caprylic acid'
# Ratio : 92
# Partial Ratio : 92
# Token sort Ratio : 100
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Oth.appar.of x-rays,f/radiography or radiotherapy' vs 'radiography'
# Ratio : 37
# Partial Ratio : 100
# Token sort Ratio : 37
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Gamma therapy apparatus f/medical,surgical,etc.' vs 'therapy'
# Ratio : 26
# Partial Ratio : 100
# Token sort Ratio : 26
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Mach.appl.f/testing tensile strength/metals compress.' vs 'tensile strength'
# Ratio : 46
# Partial Ratio : 100
# Token sort Ratio : 47
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Public central, eletron. commutator, includ. traffic' vs 'traffic'
# Ratio : 24
# Partial Ratio : 100
# Token sort Ratio : 25
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Clinical thermometers,of liquid,of direct reading' vs 'thermometers'
# Ratio : 39
# Partial Ratio : 100
# Token sort Ratio : 39
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Cartridges for riveting/captive-bolt humane killers' vs 'captive bolt'
# Ratio : 35
# Partial Ratio : 92
# Token sort Ratio : 38
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Electrophoresis instruments' vs 'electrophoresis'
# Ratio : 67
# Partial Ratio : 93
# Token sort Ratio : 71
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Automatic dna sequencing by means of capil.electrop.' vs 'dna'
# Ratio : 11
# Partial Ratio : 100
# Token sort Ratio : 11
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Spectrometers of optical emission (atomic emission )' vs 'emission'
# Ratio : 27
# Partial Ratio : 100
# Token sort Ratio : 28
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Spectrophotometers' vs 'spectrophotometers'
# Ratio : 94
# Partial Ratio : 94
# Token sort Ratio : 100
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Direction finding compasses' vs 'direction finding'
# Ratio : 73
# Partial Ratio : 94
# Token sort Ratio : 77
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Height measure for aeronautical or space navigation' vs 'navigation'
# Ratio : 33
# Partial Ratio : 100
# Token sort Ratio : 33
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Automat.pilots f/aeronautical or space navigation' vs 'pace'
# Ratio : 15
# Partial Ratio : 100
# Token sort Ratio : 15
# Token set Ratio : 15
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Rangefinders' vs 'gef'
# Ratio : 40
# Partial Ratio : 100
# Token sort Ratio : 40
# Token set Ratio : 40
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Theodolites and tachymeters,with prism,etc.prec=1sec' vs 'heod'
# Ratio : 14
# Partial Ratio : 100
# Token sort Ratio : 14
# Token set Ratio : 14
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Levels' vs 'water levels'
# Ratio : 56
# Partial Ratio : 83
# Token sort Ratio : 67
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Photogrammetrical,surveying instruments and appliances' vs 'surveying'
# Ratio : 29
# Partial Ratio : 100
# Token sort Ratio : 29
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Rods of pumping for extraction of oil' vs 'pumping'
# Ratio : 32
# Partial Ratio : 100
# Token sort Ratio : 32
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Proximity cards and tags' vs 'tags'
# Ratio : 29
# Partial Ratio : 100
# Token sort Ratio : 29
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Gener.of special effects with man.2/3 dimen.etc.f/video' vs 'effects'
# Ratio : 23
# Partial Ratio : 100
# Token sort Ratio : 23
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Other parts of aeroplanes or helicopters' vs 'helicopters'
# Ratio : 43
# Partial Ratio : 100
# Token sort Ratio : 43
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Flight simulators apparatus and parts thereof' vs 'flight'
# Ratio : 20
# Partial Ratio : 83
# Token sort Ratio : 24
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Tankers ships' vs 'tanker ships'
# Ratio : 88
# Partial Ratio : 92
# Token sort Ratio : 96
# Token set Ratio : 96
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Mount.piezo-electr.crystals,of quartzo,1<=freq<=100mhz' vs 'mh'
# Ratio : 7
# Partial Ratio : 100
# Token sort Ratio : 7
# Token set Ratio : 7
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Endoscopy' vs 'endoscopy'
# Ratio : 89
# Partial Ratio : 89
# Token sort Ratio : 100
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Microprocessors,mounted,f/surface mounted device' vs 'microprocessors'
# Ratio : 44
# Partial Ratio : 93
# Token sort Ratio : 48
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Suspension shock-absorbers f/tractors and motor vehic.' vs 'shock'
# Ratio : 17
# Partial Ratio : 100
# Token sort Ratio : 17
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Artificial respiration apparatus' vs 'artificial respiration'
# Ratio : 78
# Partial Ratio : 95
# Token sort Ratio : 81
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Appliances known as iron lungs' vs 'lungs'
# Ratio : 27
# Partial Ratio : 100
# Token sort Ratio : 29
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Ozone therapy apparatus and oth.of therapeutic respir.' vs 'ozone'
# Ratio : 14
# Partial Ratio : 80
# Token sort Ratio : 17
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Reception appar.personal of radium-mes.in screen(ecran)' vs 'radium'
# Ratio : 20
# Partial Ratio : 100
# Token sort Ratio : 20
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Electronic microassemblies' vs 'assemblies'
# Ratio : 56
# Partial Ratio : 100
# Token sort Ratio : 56
# Token set Ratio : 56
# Partial token sort Ratio : 100
# Partial token set Ratio : 100
#
# 'Ion implanters for doping semiconductor materials' vs 'doping'
# Ratio : 22
# Partial Ratio : 100
# Token sort Ratio : 22
# Token set Ratio : 100
# Partial token sort Ratio : 100
# Partial token set Ratio : 100

# %% [markdown]
# ### Combine the two processed matched csvs

# %%
dfp1 = pd.read_csv('runoharris215@gmail.com.csv')
dfp2 = pd.read_csv('processed_ids3.csv')

# %%
del(dfp1['Unnamed: 0'])
del(dfp2['Unnamed: 0'])

# %%
dfp1.tail()
# Out:
#       source_1  source_2
# 2223     11991     20106
# 2224     11995      8397
# 2225     11999     42414
# 2226     12014     33961
# 2227     12041      4663

# %%
dfp2.tail()
# Out:
#     source_1  source_2
# 88     12129     30164
# 89     12130     37661
# 90     12141     39826
# 91     12183     36565
# 92     12188      7013

# %%
frames = [dfp1, dfp2]
result = pd.concat(frames)

# %%
result.tail()
# Out:
#     source_1  source_2
# 88     12129     30164
# 89     12130     37661
# 90     12141     39826
# 91     12183     36565
# 92     12188      7013

# %%
result.reset_index(inplace=True)

# %%
result.tail()
# Out:
#       index  source_1  source_2
# 2316     88     12129     30164
# 2317     89     12130     37661
# 2318     90     12141     39826
# 2319     91     12183     36565
# 2320     92     12188      7013

# %%
result.columns
# Out:
# Index(['index', 'source_1', 'source_2'], dtype='object')

# %%
del(result['index'])

# %%
result.tail()
# Out:
#       source_1  source_2
# 2316     12129     30164
# 2317     12130     37661
# 2318     12141     39826
# 2319     12183     36565
# 2320     12188      7013

# %%
result.to_csv('runoharris215@gmail.com.csv')
