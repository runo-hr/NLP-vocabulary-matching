# %%
import pandas as pd

import nltk
from nltk.corpus import wordnet
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer

import spacy
from spacy.matcher import Matcher

from thefuzz import fuzz, process

# %% [markdown]
# # Data

# %%
# set pandas to display all rows
pd.set_option('display.max_rows', None)

# %%
# Matched examples
df_matched = pd.read_csv('matched_data.csv')
df_matched
# Out:
#                                              source_1                source_2
# 0                                     Cereals, barley                  barley
# 1                     Other fresh or chilled potatoes                potatoes
# 2                      Fruit, edible; cherries, fresh                cherries
# 3           Bran, sharps and other residues, of maize              maize bran
# 4                                     Cereals, millet                 millets
# 5     Oil seeds; sesamum seeds, whether or not broken             sesame seed
# 6                       Cigarettes containing tobacco              cigarettes
# 7                            Tomato, fresh or chilled                tomatoes
# 8   Pulp, bagasse and other waste of sugar manufac...               beet pulp
# 9   Oil seeds; sunflower seeds, whether or not broken          sunflower seed
# 10                Fruit, edible; figs, fresh or dried                    figs
# 11  Bran, sharps and other residues; of wheat, whe...              wheat bran
# 12               Bananas-of-the-earth, fresh or dried               plantains
# 13                                 Maize (corn) flour               cornflour
# 14  Dairy produce; cheese, processed (not grated o...        processed cheese
# 15                         Fresh or chilled asparagus               asparagus
# 16                               Fresh/dried avocados                avocados
# 17  Pig fat; lard, other than that of heading 0209...                    lard
# 18      Oil seeds; poppy seeds, whether or not broken              poppy seed
# 19                           Grape juice, unfermented             grape juice
# 20                                        Asses, live            equus asinus
# 21  Nuts, edible; chestnuts (castanea spp.), fresh...               chestnuts
# 22                                         Sesame oil              sesame oil
# 23                 Fruit, edible; strawberries, fresh            strawberries
# 24  Vegetables, leguminous; chickpeas (garbanzos),...               chickpeas
# 25                                       Fresh apples             crab apples
# 26                                        Wheat flour             wheat flour
# 27                                  Fresh watermelons             watermelons
# 28  Fruit, edible; sour cherries (Prunus cerasus),...           sour cherries
# 29          Oil seeds; linseed, whether or not broken                 linseed
# 30  Vegetables, leguminous; lentils, shelled, whet...                 lentils
# 31                      Fruit, edible; quinces, fresh                 quinces
# 32   Vegetables, alliaceous; garlic, fresh or chilled                  garlic
# 33            Cocoa (whole or broken), raw or roasted             cocoa beans
# 34  Waxes, other than vegetable, n.e.s. in heading...                 beeswax
# 35                                     Spices, ginger                  ginger
# 36  Vegetable roots and tubers; manioc (cassava), ...                    yuca
# 37                                        Broken rice             broken rice
# 38  Coffee; substitutes containing coffee, in any ...      coffee substitutes
# 39  Vegetables; spinach, New Zealand spinach and o...                 spinach
# 40               Vegetables; olives, fresh or chilled                  olives
# 41                       Other soybeans, even crushed                soybeans
# 42                     Fruit, edible; apricots, fresh                apricots
# 43                                       Cereals, rye                     rye
# 44  Food preparations; of flour, meal, starch, mal...           weaning foods
# 45                            Manioc (cassava) starch                 tapioca
# 46                      Live asses, mules and hinnies                  horses
# 47                             Cereals, grain sorghum                 sorghum
# 48     Oil seeds; cotton seeds, whether or not broken              cottonseed
# 49                                              Copra                   copra
# 50          Fresh/chilled/frozen/dried sweet potatoes           sweetpotatoes
# 51              Fresh/chilled aubergines (egg-plants)               eggplants
# 52  Fruit, edible; bananas, (including plantains),...                 bananas
# 53                                      Cereals, oats                    oats
# 54    Oil seeds; mustard seeds, whether or not broken            mustard seed
# 55                                       Pears, fresh                   pears
# 56  Fres/chil/froz oth.meat/edib.meat offal of rab...             rabbit meat
# 57                                 Cereals, buckwheat               buckwheat
# 58            Meat of goats, fresh, chilled or frozen               goat meat
# 59               Fruit, edible; dates, fresh or dried                   dates
# 60  Nuts, edible; kola nuts (Cola spp.), fresh or ...               kola nuts
# 61                                        Goats, live                   goats
# 62  Dairy produce; buttermilk, curdled milk or cre...              buttermilk
# 63                   Bran and other residues, of rice               rice bran
# 64                             Fresh/dried pineapples              pineapples
# 65  Nuts, edible; pistachios, fresh or dried, whet...              pistachios
# 66                                         Dry grapes                 raisins
# 67                    Butter, fat and oil, from cocoa            cocoa butter
# 68  Nuts, edible; coconuts, fresh or dried, whethe...                coconuts
# 69                                       Sauces, soya                  tamari
# 70                             Fresh papaws (papayas)  pawpaw (carica papaya)
# 71                                        Sheep, live                   sheep
# 72  Fruit, edible; cranberries, bilberries and oth...             cranberries
# 73     Spices; cloves (whole fruit, cloves and stems)                  cloves
# 74                              Fresh/chilled lettuce                cabbages
# 75  Jute and other textile bast fibres; processed ...                    jute
# 76                    Cereals, fonio (Digitaria spp.)       fonio (digitaria)
# 77  Vegetable roots and tubers; taro (Colocasia sp...                    taro
# 78  Fruit, edible; raspberries, blackberries, mulb...             raspberries
# 79  Sugar cane; fit for human consumption, fresh, ...               sugarcane
# 80  Meat and edible meat offal; of camels and othe...          dromedary meat
# 81  Vegetable roots and tubers; yams (Dioscorea sp...                    yams
# 82  Oil seeds; safflower seeds, whether or not broken          safflower seed
# 83  Oleaginous fruits; palm nuts and kernels, whet...            palm kernels
# 84  Molluscs; snails (other than sea snails), live...                  snails
# 85                                            Yoghurt                 yoghurt
# 86               Cereals, quinoa (Chenopodium quinoa)                  quinua
# 87  Vegetable roots and tubers; yautia (Xanthosoma...                  yautia
# 88  locust beans, seaweeds and other algae, sugar ...                  carobs
# 89         Oleaginous fruits, shea nuts (karite nuts)               shea nuts
# 90                                            Ploughs                   plows
# 91  Vegetables, leguminous; pigeon peas (Cajanus c...                     tur
# 92                                               Mate              yerba mate
# 93                                Maize (corn) starch            maize starch
# 94  Fish; smoked (whether or not cooked before or ...             smoked fish
# 95                             Fresh/dried grapefruit             grapefruits
# 96  Dairy produce, butter and other fats and oils ...                  butter
# 97  Oleic acid (industrial monocarboxylic fatty ac...              oleic acid
# 98  Disc harrows, used agricultural, etc.f/soil pr...            disc harrows

# %% [markdown]
# # Fuzzy string matching

# %%
lemmatizer = WordNetLemmatizer()
stemmer = LancasterStemmer()

# %%
def root_words(string):
    wrds = nltk.word_tokenize(string)
    roots = [lemmatizer.lemmatize(word.lower()) for word in wrds]
    #roots = [stemmer.stem(word.lower()) for word in wrds]
    return roots
root_words('computer')

# %%
def get_synonyms(string):
    string = string.strip()
    synonyms = []
    for syn in wordnet.synsets(string):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
    res = []
    for syn in synonyms:
        if '_' in syn:
            res.extend(syn.split('_'))
            #res.append(' '.join(syn.split('_')))
        else:
            res.append(syn)
    return res
get_synonyms('mammals   ')

# %%
matched_data = []
def get_match(source_1, source_2):
    def get_ratios(i, j):
        print(f"'{i}' vs '{j}'")

        ratio = fuzz.ratio(i, j)
        print(f"Ratio : {ratio}")

        partial_ratio = fuzz.partial_ratio(root_words(i)[0], j)
        print(f"Partial Ratio : {partial_ratio}")

        token_sort_ratio = fuzz.token_sort_ratio(i, j)
        print(f"Token sort Ratio : {token_sort_ratio}")

        token_set_ratio = fuzz.token_set_ratio(i, j)
        print(f"Token set Ratio : {token_set_ratio}")
        print()

        return partial_ratio, token_set_ratio

    for i in source_2:
        i = i.strip()
        synonyms = get_synonyms(i) if ' ' not in i else None
        all_synonyms = ''
        if synonyms:
            synonym_str = ' '.join(synonyms)
            all_synonyms = i + ' ' + synonym_str

        for j in source_1:
            partial_ratio, token_set_ratio = get_ratios(i, j)
            if token_set_ratio == 100 or partial_ratio > 80:
                matched_data.append(dict(s1=j, s2=i))
                source_2.remove(i)
                source_1.remove(j)
                return get_match(source_1, source_2)
            if len(all_synonyms) > 0:
                partial_ratio = get_ratios(all_synonyms, j)[0]
                if partial_ratio > 80:
                    matched_data.append(dict(s1=j, s2=i))
                    source_2.remove(i)
                    source_1.remove(j)
                    return get_match(source_1, source_2)
            else:
                continue
    return matched_data

# %%
# Matched examples
df_matched = pd.read_csv('matched_data.csv')
df_s1 = pd.read_csv('source_1.csv')
df_s2 = pd.read_csv('source_2.csv')

#src_1 = df_matched.source_1.to_list()
#src_2 = df_matched.source_2.to_list()
src_1 = df_s1.name.to_list()
src_2 = df_s2.name.to_list()

df_data = get_match(src_1, src_2)
df = pd.DataFrame(df_data)
print(df)

# %%
#src_1 = df_matched.source_1.to_list()
#src_2 = df_matched.source_2.to_list()

# %%
df_s1 = pd.read_csv('source_1.csv')
df_s2 = pd.read_csv('source_2.csv')
src_1 = df_s1.name.to_list()
src_2 = df_s2.name.to_list()

# %%
for i in src_1:
    print(i)
    print('partial token sort ratio')
    print(process.extractOne(i, src_2, scorer = fuzz.partial_token_sort_ratio))
    print('partial token set ratio')
    print(process.extractOne(i, src_2, scorer = fuzz.partial_token_set_ratio))
    print('token sort ratio')
    print(process.extractOne(i, src_2, scorer = fuzz.token_sort_ratio))
    print(' token set ratio')
    print(process.extractOne(i, src_2, scorer = fuzz.token_set_ratio))
    print('partial ratio')
    print(process.extractOne(i, src_2, scorer = fuzz.partial_ratio))
    print('ratio')
    print(process.extractOne(i, src_2, scorer = fuzz.ratio))
    
    print()
# Out:
# Horses, asses, mules and hinnies; live, pure-bred breeding animals
# partial token sort ratio
# ('hinnies', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('diagnosis and recommendation integrated system', 46)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('hinnies', 100)
# ratio
# ('hong kong special administrative region of china', 44)
#
# Horses; live, pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('fur bearing animals', 60)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('fur bearing animals', 58)
#
# Horses; live, other than pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('psittacine beak and feather disease', 52)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('nutrient transport in animals', 52)
#
# Horses, asses, mules and hinnies; live, other than pure-bred breeding animals
# partial token sort ratio
# ('hinnies', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('hinnies', 100)
# ratio
# ('positive sense single-stranded rna viruses', 44)
#
# Bovine animals; live, pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('bovine leukosis', 100)
# token sort ratio
# ('fur bearing animals', 52)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('oil producing animals', 52)
#
# Cattle; live, pure-bred breeding animals
# partial token sort ratio
# ('cattle', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('fur bearing animals', 60)
#  token set ratio
# ('cattle', 100)
# partial ratio
# ('cattle', 100)
# ratio
# ('fur bearing animals', 58)
#
# Cattle; live, other than pure-bred breeding animals
# partial token sort ratio
# ('cattle', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('nutrient transport in animals', 51)
#  token set ratio
# ('cattle', 100)
# partial ratio
# ('cattle', 100)
# ratio
# ('nutrient transport in animals', 52)
#
# Buffalo; live, pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('buffalo feeding', 100)
# token sort ratio
# ('fur bearing animals', 62)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('fur bearing animals', 60)
#
# Buffalo; live, other than pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('buffalo feeding', 100)
# token sort ratio
# ('fur bearing animals', 52)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('nutrient transport in animals', 52)
#
# Bovine animals; live, other than pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('bovine leukosis', 100)
# token sort ratio
# ('united kingdom of great britain and northern ireland', 48)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('nutrient transport in animals', 48)
#
# Swine; live, pure-bred breeding animals
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('fur bearing animals', 61)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('fur bearing animals', 59)
#
# Swine; live, (other than pure-bred breeding animals), weighing less than 50kg
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('psittacine beak and feather disease', 47)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('united nations framework convention on climate change', 40)
#
# Swine; live, (other than pure-bred breeding animals), weighing 50kg or more
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('dominance of animals', 100)
# token sort ratio
# ('convention on migratory species of wild animals', 46)
#  token set ratio
# ('pure breeding', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('international centre for research in agroforestry', 42)
#
# Poultry; live, fowls of the species gallus domesticus, weighing not more than 185g
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 47)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#
# Poultry; live, weighing not more than 185g, turkeys
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('height classes (in forestry)', 46)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure', 45)
#
# Poultry; live, ducks, weighing not more than 185g
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('height classes (in forestry)', 50)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('controlled designation of origin', 44)
#
# Poultry; live, geese, weighing not more than 185g
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('wasting disease (nutritional disorder)', 49)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('positive sense single-stranded rna viruses', 46)
#
# Poultry; live, guinea fowls, weighing not more than 185g
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('forest management planning', 48)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure', 43)
#
# Poultry; live, weighing not more than 185g, ducks, geese, turkeys and guinea fowls
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#
# Poultry; live, fowls of the species gallus domesticus, weighing more than 185g
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 45)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure', 46)
#
# Poultry; live, weighing over 185g but not more than 2000g, fowls of the species gallus domesticus
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 43)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 47)
#
# Poultry; live, weighing over 2000g, fowls of the species gallus domesticus
# partial token sort ratio
# ('weighing', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('genetic diversity within species', 45)
#  token set ratio
# ('weighing', 100)
# partial ratio
# ('weighing', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#
# Poultry; live, ducks, geese, turkeys and guinea fowls, weighing more than 185g
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#
# Mammals; live, camels and other camelids (Camelidae)
# partial token sort ratio
# ('camelidae', 100)
# partial token set ratio
# ('laboratory mammals', 100)
# token sort ratio
# ('south american calabash', 48)
#  token set ratio
# ('camels', 100)
# partial ratio
# ('camels', 100)
# ratio
# ('marine catfish (northern seas)', 48)
#
# Mammals; live, rabbits and hares
# partial token sort ratio
# ('hares', 100)
# partial token set ratio
# ('laboratory mammals', 100)
# token sort ratio
# ('giganthias immaculatus', 54)
#  token set ratio
# ('hares', 100)
# partial ratio
# ('hares', 100)
# ratio
# ('mammals (marine)', 55)
#
# Mammals; live, other than primates, whales, dolphins and porpoises (order Cetacea), manatees and dugongs (order Sirenia)
# partial token sort ratio
# ('cetacea', 100)
# partial token set ratio
# ('laboratory mammals', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 43)
#  token set ratio
# ('cetacea', 100)
# partial ratio
# ('cetacea', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Birds; live, ostriches; emus (Dromaius novaehollandiae)
# partial token sort ratio
# ('emus', 100)
# partial token set ratio
# ('grain eating birds', 100)
# token sort ratio
# ('jasus novaehollandiae', 56)
#  token set ratio
# ('emus', 100)
# partial ratio
# ('mus', 100)
# ratio
# ('trachurus novaezelandiae', 54)
#
# Animals; live, birds, other than birds of prey and Psittaciformes
# partial token sort ratio
# ('cifor', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('psittacine beak and feather disease', 54)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('cifor', 100)
# ratio
# ('sanitation standard operating procedures', 46)
#
# Insects; live, bees
# partial token sort ratio
# ('insects', 100)
# partial token set ratio
# ('edible insects', 100)
# token sort ratio
# ('selective breeding', 69)
#  token set ratio
# ('insects', 100)
# partial ratio
# ('insects', 100)
# ratio
# ('insectivores', 65)
#
# Insects; live, other than bees
# partial token sort ratio
# ('insects', 100)
# partial token set ratio
# ('edible insects', 100)
# token sort ratio
# ('preventive therapy', 57)
#  token set ratio
# ('insects', 100)
# partial ratio
# ('insects', 100)
# ratio
# ('marine catfish (northern seas)', 58)
#
# Animals; live, n.e.c. in chapter 01, other than mammals, reptiles and birds
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('laboratory mammals', 100)
# token sort ratio
# ('saint helena, ascension and tristan da cunha', 48)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('mhs (malignant hyperthermia syndro)', 44)
#
# Meat; of bovine animals, carcasses and half-carcasses, fresh or chilled
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('health certification of aquatic animals', 45)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('african, caribbean and pacific group of states', 43)
#
# Meat; of bovine animals, cuts with bone in (excluding carcasses and half-carcasses), fresh or chilled
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 44)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 42)
#
# Meat; of bovine animals, boneless cuts, fresh or chilled
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('nutrient balance (animals)', 49)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('center for international forestry research', 49)
#
# Meat; of bovine animals, carcasses and half-carcasses, frozen
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('health certification of aquatic animals', 52)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('eia (environmental impact assessment)', 45)
#
# Meat; of bovine animals, cuts with bone in (excluding carcasses and half-carcasses), frozen
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('economic and social commission for asia and the pacific', 43)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 44)
#
# Meat; of bovine animals, boneless cuts, frozen
# partial token sort ratio
# ('frozen meat', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('nutrient balance (animals)', 57)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('musle (modified universal soil loss equation)', 51)
#
# Meat; of swine, carcasses and half-carcasses, fresh or chilled
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('forest monitoring and assessment', 51)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('center for international forestry research', 46)
#
# Meat; of swine, hams, shoulders and cuts thereof, with bone in, fresh or chilled
# partial token sort ratio
# ('ms', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 52)
#  token set ratio
# ('hams', 100)
# partial ratio
# ('hams', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 43)
#
# Meat; of swine, n.e.s. in item no. 0203.1, fresh or chilled
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('emulsions (oil in water)', 100)
# token sort ratio
# ('controlled designation of origin', 49)
#  token set ratio
# ('fresh meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('number of seedling per hill', 44)
#
# Meat; of swine, carcasses and half-carcasses, frozen
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('forest monitoring and assessment', 52)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('resilience to shocks and crises', 46)
#
# Meat; of swine, hams, shoulders and cuts thereof, with bone in, frozen
# partial token sort ratio
# ('ms', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 51)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('hams', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 44)
#
# Meat; of swine, n.e.s. in item no. 0203.2, frozen
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('emulsions (oil in water)', 100)
# token sort ratio
# ('french west indies (martinique)', 47)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('negative sense single-stranded rna viruses', 44)
#
# Meat; of sheep, lamb carcasses and half-carcasses, fresh or chilled
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('resilience to shocks and crises', 46)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('macao special administrative region of china', 41)
#
# Meat; of sheep, carcasses and half-carcasses (excluding carcasses and half-carcasses of lamb), fresh or chilled
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 42)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 41)
#
# Meat; of sheep (including lamb), cuts with bone in (excluding carcasses and half-carcasses), fresh or chilled
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 45)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Meat; of sheep (including lamb), boneless cuts, fresh or chilled
# partial token sort ratio
# ('lamb meat', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('explicit mention of international treaties', 44)
#  token set ratio
# ('lamb meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('number of seedling per hill', 46)
#
# Meat; of sheep, lamb carcasses and half-carcasses, frozen
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('resilience to shocks and crises', 47)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('saint helena, ascension and tristan da cunha', 44)
#
# Meat; of sheep, carcasses and half-carcasses (excluding carcasses and half-carcasses of lamb), frozen
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('economic and social commission for asia and the pacific', 42)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 42)
#
# Meat; of sheep (including lamb), cuts with bone in (excluding carcasses and half-carcasses), frozen
# partial token sort ratio
# ('carcasses', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 44)
#  token set ratio
# ('carcasses', 100)
# partial ratio
# ('carcasses', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 40)
#
# Meat; of sheep (including lamb), boneless cuts, frozen
# partial token sort ratio
# ('lamb meat', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('crocus biflorus subsp. fibroannulatus', 47)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('vespicula depressifrons', 44)
#
# Meat; of horses, asses, mules or hinnies, fresh, chilled or frozen
# partial token sort ratio
# ('hinnies', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('world reference base for soil resources groups', 47)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('hinnies', 100)
# ratio
# ('severe acute respiratory syndrome-related coronavirus', 42)
#
# Offal, edible; of bovine animals, fresh or chilled
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('feeds of animal origin', 49)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('ownership of natural resources', 48)
#
# Offal, edible; of bovine animals, tongues, frozen
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('animal developmental stages', 56)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('juvenile hormone analogues', 51)
#
# Offal, edible; of bovine animals, livers, frozen
# partial token sort ratio
# ('liver', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('convention on migratory species of wild animals', 53)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('liver', 100)
# ratio
# ('bovine viral diarrhoea', 46)
#
# Offal, edible; of bovine animals, (other than tongues and livers), frozen
# partial token sort ratio
# ('liver', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations economic and social commission for asia and the pacific', 51)
#  token set ratio
# ('animals', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 48)
#
# Offal, edible; of swine, fresh or chilled
# partial token sort ratio
# ('offal', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('number of seedling per hill', 52)
#  token set ratio
# ('offal', 100)
# partial ratio
# ('offal', 100)
# ratio
# ('number of seedling per hill', 50)
#
# Offal, edible; of swine, livers, frozen
# partial token sort ratio
# ('liver', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('deep frozen storage', 52)
#  token set ratio
# ('offal', 100)
# partial ratio
# ('liver', 100)
# ratio
# ('republic of sierra leone', 48)
#
# Offal, edible; of swine, (other than livers), frozen
# partial token sort ratio
# ('liver', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('deep-sea lobster fisheries', 50)
#  token set ratio
# ('offal', 100)
# partial ratio
# ('liver', 100)
# ratio
# ('labour saving technologies for women', 50)
#
# Offal, edible; of sheep, goats, horses, asses, mules or hinnies, fresh or chilled
# partial token sort ratio
# ('goa', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('convention on the elimination of all forms of discrimination against women', 45)
#  token set ratio
# ('hinnies', 100)
# partial ratio
# ('goa', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#
# Offal, edible; of sheep, goats, horses, asses, mules or hinnies, frozen
# partial token sort ratio
# ('goa', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('world reference base for soil resources groups', 47)
#  token set ratio
# ('hinnies', 100)
# partial ratio
# ('goa', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#
# Meat and edible offal; of the poultry of heading no. 0105, of fowls of the species gallus domesticus, (not cut in pieces), fresh or chilled
# partial token sort ratio
# ('gallus', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 45)
#  token set ratio
# ('gallus', 100)
# partial ratio
# ('gallus', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Meat and edible offal; of the poultry of heading no. 0105, of fowls of the species gallus domesticus, (not cut in pieces), frozen
# partial token sort ratio
# ('gallus', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 47)
#  token set ratio
# ('gallus', 100)
# partial ratio
# ('gallus', 100)
# ratio
# ('convention on the elimination of all forms of discrimination against women', 41)
#
# Meat and edible offal; of the poultry of heading no. 0105, of fowls of the species gallus domesticus, cuts and offal, fresh or chilled
# partial token sort ratio
# ('gallus', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#  token set ratio
# ('gallus', 100)
# partial ratio
# ('gallus', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 40)
#
# Meat and edible offal; of the poultry of heading no. 0105, of fowls of the species gallus domesticus, cuts and offal, frozen
# partial token sort ratio
# ('gallus', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 46)
#  token set ratio
# ('gallus', 100)
# partial ratio
# ('gallus', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 41)
#
# Meat and edible offal; turkeys, not cut in pieces, frozen
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 51)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('wasting disease (nutritional disorder)', 45)
#
# Meat and edible offal; of the poultry of heading no. 0105, of turkeys, (not cut in pieces), fresh or chilled
# partial token sort ratio
# ('head', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 50)
#  token set ratio
# ('heading', 100)
# partial ratio
# ('head', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#
# Meat and edible offal; of the poultry of heading no. 0105, of turkeys, cuts and offal, fresh or chilled
# partial token sort ratio
# ('head', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 49)
#  token set ratio
# ('heading', 100)
# partial ratio
# ('head', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#
# Meat and edible offal; of the poultry of heading no. 0105, of turkeys, cuts and offal, frozen
# partial token sort ratio
# ('head', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 48)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('head', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#
# Offal, edible; of geese or ducks, fatty livers, fresh or chilled
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('parenchyma of invertebrates', 100)
# token sort ratio
# ('code of conduct for responsible fisheries', 46)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('fatty liver', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#
# Meat and edible offal; of the poultry of heading no. 0105, of ducks, geese or guinea fowls, (not cut in pieces), fresh or chilled
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 47)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Meat and edible offal; of the poultry of heading no. 0105, of ducks, geese or guinea fowls, (not cut in pieces), frozen
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 48)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Meat and edible offal; of the poultry of heading no. 0105, of ducks, geese or guinea fowls, fresh or chilled, poultry cuts or offal (excluding fatty livers)
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('fatty liver', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Meat and edible offal; of the poultry of heading no. 0105, of ducks, geese or guinea fowls, frozen
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 50)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#
# Meat and edible offal; of fowls of the species gallus domesticus, poultry cuts and offal (excluding livers), frozen
# partial token sort ratio
# ('gallus', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 49)
#  token set ratio
# ('gallus', 100)
# partial ratio
# ('gallus', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 43)
#
# Meat and edible offal; of turkeys, poultry cuts and offal (excluding livers), frozen
# partial token sort ratio
# ('liver', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 47)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('liver', 100)
# ratio
# ('international bank for reconstruction and development', 42)
#
# Meat and edible offal; of ducks, geese or guinea fowls, poultry cuts and offal (excluding livers) frozen
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 48)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('ducks', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Meat and edible offal; of ducks, cuts and offal, excluding fatty livers, fresh or chilled
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 43)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('fatty liver', 100)
# ratio
# ('macao special administrative region of china', 41)
#
# Meat and edible offal; of ducks, cuts and offal, excluding fatty livers, frozen
# partial token sort ratio
# ('ducks', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('economic and social commission for asia and the pacific', 45)
#  token set ratio
# ('ducks', 100)
# partial ratio
# ('fatty liver', 100)
# ratio
# ('united nations educational, scientific and cultural organization', 42)
#
# Meat and edible offal; of geese, not cut in pieces, fresh or chilled
# partial token sort ratio
# ('geese', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 46)
#  token set ratio
# ('geese', 100)
# partial ratio
# ('geese', 100)
# ratio
# ('wasting disease (nutritional disorder)', 44)
#
# Meat and edible offal; of geese, not cut in pieces, frozen
# partial token sort ratio
# ('geese', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on migratory species of wild animals', 51)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('geese', 100)
# ratio
# ('wasting disease (nutritional disorder)', 46)
#
# Meat and edible offal; of geese, cuts and offal, excluding fatty livers, fresh or chilled
# partial token sort ratio
# ('geese', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 43)
#  token set ratio
# ('geese', 100)
# partial ratio
# ('fatty liver', 100)
# ratio
# ('macao special administrative region of china', 42)
#
# Meat and edible offal; of geese, cuts and offal, excluding fatty livers, frozen
# partial token sort ratio
# ('geese', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 43)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('fatty liver', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 42)
#
# Meat and edible offal; of guinea fowls, fresh, chilled or frozen
# partial token sort ratio
# ('guinea', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 48)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('guinea', 100)
# ratio
# ('international union of forest research organizations', 45)
#
# Meat and edible meat offal; of whales, dolphins and porpoises (mammals of the order Cetacea) and manatees and dugongs (mammals of the order Sirenia), fresh, chilled or frozen
# partial token sort ratio
# ('cetacea', 100)
# partial token set ratio
# ('laboratory mammals', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 40)
#  token set ratio
# ('cetacea', 100)
# partial ratio
# ('cetacea', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#
# Meat and edible meat offal; n.e.s. in chapter 2, fresh, chilled or frozen
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations conference on environment and development', 46)
#  token set ratio
# ('frozen meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 43)
#
# Fat; pig fat, free of lean meat, and poultry fat, (not rendered), fresh, chilled, frozen, salted, in brine, dried or smoked
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 47)
#  token set ratio
# ('dried meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 42)
#
# Fat; pig fat, free of lean meat, not rendered or otherwise extracted, fresh, chilled, frozen, salted, in brine, dried or smoked
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('free-fall equipment', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 45)
#  token set ratio
# ('dried meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 41)
#
# Fat; poultry fat, not rendered or otherwise extracted, fresh, chilled, frozen, salted, in brine, dried or smoked
# partial token sort ratio
# ('poultry', 100)
# partial token set ratio
# ('poultry breeds', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 45)
#  token set ratio
# ('poultry', 100)
# partial ratio
# ('poultry', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#
# Meat, preserved; of swine, hams, shoulders and cuts thereof, with bone in, salted, in brine, dried or smoked
# partial token sort ratio
# ('ms', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 48)
#  token set ratio
# ('dried meat', 100)
# partial ratio
# ('hams', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Meat, preserved; of swine, bellies (streaky) and cuts thereof, salted, in brine, dried or smoked
# partial token sort ratio
# ('bel', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 48)
#  token set ratio
# ('dried meat', 100)
# partial ratio
# ('bel', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 43)
#
# Meat, preserved; of swine, salted, in brine, dried or smoked, n.e.s. in item no. 0210.1
# partial token sort ratio
# ('meat', 100)
# partial token set ratio
# ('emulsions (oil in water)', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 47)
#  token set ratio
# ('dried meat', 100)
# partial ratio
# ('meat', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 40)
#
# Meat, preserved; of bovine animals, salted, in brine, dried or smoked
# partial token sort ratio
# ('animals', 100)
# partial token set ratio
# ('emulsions (oil in water)', 100)
# token sort ratio
# ('convention on migratory species of wild animals', 54)
#  token set ratio
# ('dried meat', 100)
# partial ratio
# ('animals', 100)
# ratio
# ('psbmv (pea seed-borne mosaic virus)', 45)
#
# Meat and edible meat offal, preserved; salted, in brine, dried or smoked, and edible flours and meals of meat or meat offal, other than of primates,whales, dolphins and porpoises, manatees and dugongs, reptiles (including snakes and turtles)
# partial token sort ratio
# ('dolphins', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 37)
#  token set ratio
# ('dolphins', 100)
# partial ratio
# ('dolphins', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Fish; live, trout (salmo trutta, salmo gairdneri, salmo clarki, salmo aguabonita, salmo gilae)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('fermented fish paste', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('convention on international trade in endangered species of wild fauna and flora', 42)
#
# Fish; live, eels (anguilla spp.)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('fermented fish paste', 100)
# token sort ratio
# ('clarias anguillaris', 61)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('taenioides anguillaris', 54)
#
# Fish; live, carp
# partial token sort ratio
# ('carp', 100)
# partial token set ratio
# ('fermented fish paste', 100)
# token sort ratio
# ('silver carp', 72)
#  token set ratio
# ('carp', 100)
# partial ratio
# ('carp', 100)
# ratio
# ('silver carp', 67)
#
# Fish; live, bluefin tunas (Thunnus thynnus)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('fermented fish paste', 100)
# token sort ratio
# ('thunnus thynnus', 56)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('thunnus thynnus', 53)
#
# Fish; live, southern bluefin tunas (Thunnus maccoyii)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('fermented fish paste', 100)
# token sort ratio
# ('southern plains states (usa)', 51)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('southern plains states (usa)', 53)
#
# Fish; trout (salmo trutta, salmo gairdneri, salmo clarki, salmo aguabonita, salmo gilae), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 39)
#
# Fish; Pacific salmon (oncorhynchus spp.), Atlantic salmon (salmo salar), Danube salmon (hucho hucho), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('salmo salar', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#  token set ratio
# ('salmo salar', 100)
# partial ratio
# ('salmo salar', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 37)
#
# Fish; fresh or chilled, Pacific salmon (Oncorhynchus nerka, Oncorhynchus gorbuscha, Oncorhynchus keta, Oncorhynchus tschawytscha, Oncorhynchus kisutch, Oncorhynchus masou, Oncorhynchus rhodurus), not fillets, livers, roes, other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 35)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 31)
#
# Fish; fresh or chilled, Atlantic salmon (Salmo salar) and Danube salmon (Hucho hucho), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('salmo salar', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#  token set ratio
# ('salmo salar', 100)
# partial ratio
# ('salmo salar', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Fish; salmonidae, fresh or chilled, n.e.s. in item no. 0302.1 (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 45)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 40)
#
# Fish; halibut (reinhardtius hippoglossoides, hippoglossus hippoglossus, hippoglossus stenolepis), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#
# Fish; plaice (pleuronectes platessa), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 43)
#
# Fish; sole (solea spp.), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Fish; fresh or chilled, turbots (Psetta maxima, Scophthalmidae), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#  token set ratio
# ('psetta maxima', 100)
# partial ratio
# ('psetta maxima', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; flat fish, fresh or chilled, n.e.s. in item no. 0302.2 (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on the elimination of all forms of discrimination against women', 43)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 39)
#
# Fish; albacore or longfinned tunas (thunnus alalunga), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 44)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Fish; yellowfin tunas (thunnus albacares), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 43)
#
# Fish; skipjack or stripe-bellied bonito, fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('bel', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 44)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('bel', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 42)
#
# Fish; bigeye tunas (Thunnus obesus), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ...
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 39)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('rattus', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 37)
#
# Fish; haddock (melanogrammus aeglefinus), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('doc', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on the elimination of all forms of discrimination against women', 48)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('doc', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; coalfish (pollachius virens), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 44)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 44)
#
# Fish; mackerel (scomber scombrus, scomber australasicus, scomber japonicus), fresh of chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 44)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Fish; dogfish and other sharks, fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 47)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Fish; eels (anguilla spp.), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on the elimination of all forms of discrimination against women', 44)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Fish; swordfish (Xiphias gladius), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 44)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; toothfish (Dissostichus spp.), fresh or chilled (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 43)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; fresh or chilled, tilapias (Oreochromis spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; fresh or chilled, catfish (Pangasius spp., Silurus spp., Clarias spp., Ictalurus spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 41)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#
# Fish; fresh or chilled, carp (Cyprinus carpio, Carassius carassius, Ctenopharyngodon idellus, Hypophthalmichthys spp., Cirrhinus spp., Mylopharyngodon piceus), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('carassius', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#  token set ratio
# ('carassius', 100)
# partial ratio
# ('carassius', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 34)
#
# Fish; fresh or chilled, eels (Anguilla spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#
# Fish; fresh or chilled, dogfish and other sharks, excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 46)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Fish; fresh or chilled, rays and skates (Rajidae), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 43)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#
# Fish; fresh or chilled, toothfish (Dissostichus spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 39)
#
# Fish; fresh or chilled, seabass (Dicentrarchus spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; fresh or chilled, seabream (Sparidae), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('bream', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on international trade in endangered species of wild fauna and flora', 45)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('bream', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 44)
#
# Fish; Pacific salmon, sockeye salmon, (red salmon), (Oncorhynchus nerka,) frozen, (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 43)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 39)
#
# Fish; frozen, Pacific salmon (Oncorhynchus gorbuscha/keta/tschawytscha/ kisutch/masou/rhodurus) other than sockeye salmon (Oncorhynchus nerka), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 38)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 36)
#
# Fish; frozen, Atlantic salmon (Salmo salar) and Danube salmon (Hucho hucho), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('salmo salar', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 40)
#  token set ratio
# ('salmo salar', 100)
# partial ratio
# ('salmo salar', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; frozen, trout (Salmo trutta, Oncorhynchus mykiss, Oncorhynchus clarki, Oncorhynchus aguabonita, Oncorhynchus gilae, Oncorhynchus apache and Oncorhynchus chrysogaster), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 35)
#
# Fish; Pacific salmon, other than sockeye salmon, (Oncorhynchus gorbuscha/keta/tschawytscha/kisutch/masou/rhodurus), frozen, (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('infectious salmon anaemia', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 41)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 37)
#
# Fish; trout (salmo trutta, salmo gairdneri, salmo clarki, salmo aguabonita, salmo gilae), frozen (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; frozen, tilapias (Oreochromis spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 45)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; frozen, catfish (Pangasius spp., Silurus spp., Clarias spp., Ictalurus spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('voluntary guidelines on the responsible governance of tenure of land, fisheries and forests', 42)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#
# Fish; frozen, carp (Cyprinus carpio, Carassius carassius, Ctenopharyngodon idellus, Hypophthalmichthys spp., Cirrhinus spp., Mylopharyngodon piceus), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('carassius', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 38)
#  token set ratio
# ('carassius', 100)
# partial ratio
# ('carassius', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 35)
#
# Fish; frozen, eels (Anguilla spp.), excluding fillets, livers, roes, and other fish meat of heading 0304
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('convention on the elimination of all forms of discrimination against women', 45)
#  token set ratio
# ('fish', 100)
# partial ratio
# ('fish', 100)
# ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 41)
#
# Fish; salmonidae, frozen, n.e.s. in item no. 0302.1 and 0302.2 (excluding fillets, livers, roes and other fish meat of heading no. 0304)
# partial token sort ratio
# ('fish', 100)
# partial token set ratio
# ('goal 11 sustainable cities and communities', 100)
# token sort ratio
# ('united nations collaborative programme on reducing emissions from deforestation and forest degradation in developing countries', 43)
#  token set ratio
